# %% [markdown]
# # **UCI HAR - CNN + GRU Classification**
# - 모델 구조 참고 논문 : A Multichannel CNN-GRU Model for Human Activity Recognition
#   - Layer : MultiChannel CNN 3개(3x3, 5x5, 7x7) + GRU 2개 + Dense 1개

# %% [markdown]
# ---

# %% [markdown]
# # **Single Path vs MultiChannel CNN**
#   - Single Path
#     - 방식 : 직렬연결 (단일경로)
#     - 비유 : 고속도로에서 차가 터널을 '하나씩 차례대로' 통과하는 것
#     - 과정 : 입력 데이터가 Layer 1을 지나고, 그 결과가 다시 Layer 2로 들어가는 순차적인 과정
#     - Single Path의 근본적 한계
#       - 정보의 간섭 : '이전 층에서 뽑아놓은 특징'을 '다음 층의 필터'가 강제로 받아들여야 함.
#       - 필터 사이즈가 커져도 초기 정보가 이미 국소적(Local)으로 갇혀버리는 문제가 발생.
#       - 다양한 관점의 특징들을 모두 살리지 못 하고, 차례대로 가공되며 정보를 잃거나 변형됨. (다양한 시간적·공간적 특징 추출에 한계)
#   - MultiChannel CNN
#     - 방식 : 병렬연결
#     - 비유 : 갈림길이 있는 '고속도로 톨게이트'
#     - 과정
#       1. 데이터가 입구에서 똑같이 복사되어 여러 갈래의 길(채널)로 동시에 들어감.
#       2. 각 채널은 서로 다른 조건(논문에서는 서로 다른 커널 사이즈)을 갖고 있음.
#       3. 각 채널을 통과한 데이터들은 각기 다른 특징을 추출.
#       4. 마지막에 Concatenation 층에서 이 정보들을 모두 연결시켜 하나의 데이터로 출력.
#     - Single Path 대신 MultiChannel을 사용하는 이유
#       - 입력 원본 데이터를 서로 다른 필터들이 각자 '독립적'으로 '동시에' 관찰 > 정보의 입체감이 살아남.
#       - 각 필터 사이즈별로 더 깊은 학습(더 자세하고 순도 높은 특징 추출)이 가능 > 다양한 스케일의 특징을 효과적으로 추출 가능.
#       - 마지막에 이 정보들을 합침으로써, '아주 자세한 특징 + 큼직한 흐름'을 모두 가진 입체적인 모델 설계 가능.

# %% [markdown]
# # **LSTM vs GRU**
# - 이 논문에서는 왜 GRU 구조를 택했을까?
#   - 궁극적으로는 "불필요한 복잡함을 걷어내고, 정확도는 지키면서 연산 속도는 높이는, [성능은 유지하면서, 효율성을 극대화] 하기 위해"
#   1. 연산 효율성과 속도
#       - 스마트폰 센서 데이터나 라즈베리 파이와 같은 'Edge Device'에서 실시간 동작 인식을 수행하려면 모델이 가벼워야 함.
#       - 구조적 단순함: LSTM은 3개의 게이트(Forget, Input, Output)를 관리해야 하지만, GRU는 2개의 게이트(Update, Reset)만 사용.
#       - 파라미터 개수: GRU는 파라미터 수가 적어 모델이 가볍고, 연산 횟수가 적음. (즉, 실시간 처리 시 지연 시간을 줄이는 데 결정적)
#   2. 센서 데이터의 특성
#       - 센서 데이터(가속도, 자이로스코프 등)는 상대적으로 패턴이 단순하고 데이터의 '시계열 의존성'이 아주 길지 않은 편.
#       - LSTM은 매우 '긴 문맥(오래전 기억)'을 보존하는 데 최적화되어 있음.
#       - 센서 데이터는 짧은 윈도우(Time Window) 내에서 발생하는 즉각적인 패턴이 중요.
#       - So, 굳이 복잡한 LSTM을 쓸 필요가 없다고 판단.
#   3. 과적합(Overfitting) 방지
#       - 데이터셋 규모가 크지 않은 센서 데이터는 모델이 너무 복잡하면 쉽게 과적합이 발생.
#       - 데이터의 일반적인 특징을 비교적 더 간결하게 학습하는 경향 = 새로운 사람의 동작 데이터에 대해서도 더 유연하게 대처(일반화) 가능.

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers, Input, Model, backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Conv1D, BatchNormalization, ReLU, MaxPooling1D, GlobalAveragePooling1D, GRU, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

LABELS = [
    "WALKING",
    "WALKING_UPSTAIRS",
    "WALKING_DOWNSTAIRS",
    "SITTING",
    "STANDING",
    "LAYING"
]

# %%
TRAIN = "train/"
TEST = "test/"

DATASET_PATH = "/content/drive/MyDrive/AI_assignment/UCI_HAR_Dataset/"

# %%
# Load "X"
def load_X(X_signals_paths):
    X_signals = []

    for signal_type_path in X_signals_paths:
        series_list = []                                        # 한 센서축 데이터 전체 저장

        with open(signal_type_path, 'r') as file:
            for row in file:
                row_clean = row.replace('  ', ' ')              # 공백 2개를 1개로
                row_clean = row_clean.strip()                   # 양쪽 공백 제거
                serie = row_clean.split(' ')                    # 공백 기준 split
                serie_array = np.array(serie, dtype=np.float32) # float32 numpy 배열로 변환
                series_list.append(serie_array)                 # 시퀀스 추가

        # 하나의 센서축 데이터 추가 (feature)
        X_signals.append(series_list)

    # shape: (특성 수, 샘플 수, 타임스텝 수)
    X_signals = np.array(X_signals)
    # shape 변환 → (샘플 수, 타임스텝 수, 특성 수)
    return np.transpose(X_signals, (1, 2, 0))


X_train_signals_paths = [
    DATASET_PATH + TRAIN + "Inertial_Signals/" + signal + "train.txt"
    for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    DATASET_PATH + TEST + "Inertial_Signals/" + signal + "test.txt"
    for signal in INPUT_SIGNAL_TYPES
]

X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("첫 번째 샘플 데이터:\n", X_train[0])
# Out:
# X_train shape: (7352, 128, 9)
# X_test shape: (2947, 128, 9)
# 첫 번째 샘플 데이터:
#  [[ 1.808515e-04  1.076681e-02  5.556068e-02 ...  1.012817e+00
#   -1.232167e-01  1.029341e-01]
#  [ 1.013856e-02  6.579480e-03  5.512483e-02 ...  1.022833e+00
#   -1.268756e-01  1.056872e-01]
#  [ 9.275574e-03  8.928878e-03  4.840473e-02 ...  1.022028e+00
#   -1.240037e-01  1.021025e-01]
#  ...
#  [-1.147484e-03  1.714439e-04  2.647864e-03 ...  1.018445e+00
#   -1.240696e-01  1.003852e-01]
#  [-2.222655e-04  1.574181e-03  2.381057e-03 ...  1.019372e+00
#   -1.227451e-01  9.987355e-02]
#  [ 1.575500e-03  3.070189e-03 -2.269757e-03 ...  1.021171e+00
#   -1.213260e-01  9.498741e-02]]

# %%
# Load "y"

def load_y(y_path):
    with open(y_path, 'r') as file:
        labels = [int(line.strip()) for line in file]
    return np.array(labels, dtype=np.int32) - 1               # 라벨을 0부터 시작하도록 -1 (원래 라벨이 1부터 시작)

y_train_path = DATASET_PATH + TRAIN + "y_train.txt"
y_test_path = DATASET_PATH + TEST + "y_test.txt"

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)

# 정답(라벨) 데이터를 원-핫 인코딩으로 변환
y_train_onehot = to_categorical(y_train)
y_test_onehot = to_categorical(y_test)

print("y_train shape:", y_train_onehot.shape)
print("y_test shape:", y_test_onehot.shape)
print(y_train[:5])
# Out:
# y_train shape: (7352, 6)
# y_test shape: (2947, 6)
# [4 4 4 4 4]

# %% [markdown]
# # 모델 생성
# - 왜 channel 3개(3x3, 5x5, 7x7)가 최적일까? (논문의 'FIGURE 10, FIGURE 11' 참고)
#   - 채널이 1개일 때: 특정 필터 크기의 특징만 뽑을 수 있어 정보가 편향됨. (ex. 너무 국소적인 정보만 추출)
#   - 채널이 2개일 때: 어느 정도 개선되지만, 센서 데이터의 복잡한 움직임을 모두 담기엔 부족함.
#   - 채널이 3개일 때 (3x3, 5x5, 7x7):
#     - 3x3: 아주 짧은 순간의 세밀한 움직임 포착
#     - 5x5: 적절한 중간 규모의 패턴 포착
#     - 7x7: 큰 동작의 흐름 포착
#   - 채널이 4~5개 이상일 때:
#     - 모델이 너무 무거워지고 계산량이 폭증함.
#     - 이미 7x7 정도의 필터로도 충분히 큰 패턴을 보고 있는데, 9x9, 11x11을 더 추가한다고 해서 정확도가 효과적으로 늘어나지는 않음.
#     - 오히려 중복된 정보만 늘어나 과적합(Overfitting) 발생

# %%
input_shape = (X_train.shape[1], X_train.shape[2])
num_classes = 6

tf.keras.backend.clear_session()

# 1. 입력(input) 재정의
inputs = Input(shape=input_shape)

# 2. MultiChannel CNN 정의
# Layer : cConv층 2개 (L2규제 + BN + MaxPooling)
def cnn_channel(x, kernel_size):
    x = Conv1D(64, kernel_size, padding='same', kernel_regularizer=regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Conv1D(128, kernel_size, padding='same', kernel_regularizer=regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = MaxPooling1D(2)(x)
    return x

# 3. 각기 다른 커널 사이즈로 3개의 채널 생성 (3x3, 5x5, 7x7)
channel1 = cnn_channel(inputs, 3)
channel2 = cnn_channel(inputs, 5)
channel3 = cnn_channel(inputs, 7)

# 4. 채널 합치기 (Concatenate)
merged = Concatenate()([channel1, channel2, channel3])

# 5. GRU층 2개 (논문의 구조 참고)
x = GRU(128, return_sequences=True)(merged)
x = GRU(64, return_sequences=True)(x)

# 6. 출력 전처리
x = GlobalAveragePooling1D()(x)       # 모든 시간 특징을 평균으로 압축
x = BatchNormalization()(x)

# 7. 최종 출력층 Dense
outputs = Dense(num_classes, activation='softmax')(x)

# 모델 생성
model = Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['categorical_accuracy']
)

print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 9)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 128, 64)   │      1,792 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 128, 64)   │      2,944 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 128, 64)   │      4,096 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 64)   │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 64)   │        256 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 64)   │        256 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 128, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 128, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 128, 128)  │     24,704 │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 128, 128)  │     41,088 │ re_lu_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 128, 128)  │     57,472 │ re_lu_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128)  │        512 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128)  │        512 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128)  │        512 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 128, 128)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 128, 128)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 64, 128)   │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 64, 128)   │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 64, 128)   │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 384)   │          0 │ max_pooling1d[0]… │
# │ (Concatenate)       │                   │            │ max_pooling1d_1[… │
# │                     │                   │            │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 64, 128)   │    197,376 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_1 (GRU)         │ (None, 64, 64)    │     37,248 │ gru[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ gru_1[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ global_average_p… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 6)         │        390 │ batch_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 369,670 (1.41 MB)
#  Trainable params: 368,390 (1.41 MB)
#  Non-trainable params: 1,280 (5.00 KB)
# None

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# # callbacks

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_HAR_CNN+GRU_best.keras",
                save_best_only=True,
                monitor="val_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_categorical_accuracy",
                patience=30,
                verbose=1,
                mode='max',
                restore_best_weights=True
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=8,
                min_lr=0.00001,
                verbose=1
            )
        ]

# %% [markdown]
# # 모델 학습

# %%
history = model.fit(
            X_train, y_train_onehot,
            epochs=100,
            batch_size=16,
            validation_split=0.2,
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.8653 - loss: 0.6734
# Epoch 1: val_categorical_accuracy improved from None to 0.88443, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 1: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - categorical_accuracy: 0.9152 - loss: 0.4928 - val_categorical_accuracy: 0.8844 - val_loss: 0.5028 - learning_rate: 0.0010
# Epoch 2/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9412 - loss: 0.3487
# Epoch 2: val_categorical_accuracy improved from 0.88443 to 0.90687, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 2: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - categorical_accuracy: 0.9420 - loss: 0.3246 - val_categorical_accuracy: 0.9069 - val_loss: 0.4349 - learning_rate: 0.0010
# Epoch 3/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9386 - loss: 0.2673
# Epoch 3: val_categorical_accuracy improved from 0.90687 to 0.91910, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 3: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9447 - loss: 0.2448 - val_categorical_accuracy: 0.9191 - val_loss: 0.3709 - learning_rate: 0.0010
# Epoch 4/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9404 - loss: 0.2266
# Epoch 4: val_categorical_accuracy did not improve from 0.91910
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - categorical_accuracy: 0.9345 - loss: 0.2350 - val_categorical_accuracy: 0.9048 - val_loss: 0.3325 - learning_rate: 0.0010
# Epoch 5/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9443 - loss: 0.2023
# Epoch 5: val_categorical_accuracy did not improve from 0.91910
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9432 - loss: 0.1919 - val_categorical_accuracy: 0.9184 - val_loss: 0.3055 - learning_rate: 0.0010
# Epoch 6/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9537 - loss: 0.1626
# Epoch 6: val_categorical_accuracy did not improve from 0.91910
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - categorical_accuracy: 0.9486 - loss: 0.1742 - val_categorical_accuracy: 0.9116 - val_loss: 0.3244 - learning_rate: 0.0010
# Epoch 7/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9456 - loss: 0.1823
# Epoch 7: val_categorical_accuracy did not improve from 0.91910
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - categorical_accuracy: 0.9475 - loss: 0.1801 - val_categorical_accuracy: 0.9048 - val_loss: 0.2952 - learning_rate: 0.0010
# Epoch 8/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9490 - loss: 0.1683
# Epoch 8: val_categorical_accuracy did not improve from 0.91910
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9481 - loss: 0.1669 - val_categorical_accuracy: 0.9177 - val_loss: 0.2529 - learning_rate: 0.0010
# Epoch 9/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9482 - loss: 0.1535
# Epoch 9: val_categorical_accuracy did not improve from 0.91910
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - categorical_accuracy: 0.9473 - loss: 0.1556 - val_categorical_accuracy: 0.9096 - val_loss: 0.2883 - learning_rate: 0.0010
# Epoch 10/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9493 - loss: 0.1674
# Epoch 10: val_categorical_accuracy did not improve from 0.91910
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9454 - loss: 0.1752 - val_categorical_accuracy: 0.9096 - val_loss: 0.3162 - learning_rate: 0.0010
# Epoch 11/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9470 - loss: 0.1688
# Epoch 11: val_categorical_accuracy did not improve from 0.91910
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - categorical_accuracy: 0.9515 - loss: 0.1512 - val_categorical_accuracy: 0.8987 - val_loss: 0.3243 - learning_rate: 0.0010
# Epoch 12/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9558 - loss: 0.1507
# Epoch 12: val_categorical_accuracy improved from 0.91910 to 0.94018, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 12: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9514 - loss: 0.1525 - val_categorical_accuracy: 0.9402 - val_loss: 0.2796 - learning_rate: 0.0010
# Epoch 13/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9475 - loss: 0.1493
# Epoch 13: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - categorical_accuracy: 0.9469 - loss: 0.1552 - val_categorical_accuracy: 0.9150 - val_loss: 0.2478 - learning_rate: 0.0010
# Epoch 14/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9449 - loss: 0.1432
# Epoch 14: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - categorical_accuracy: 0.9418 - loss: 0.1577 - val_categorical_accuracy: 0.9157 - val_loss: 0.3739 - learning_rate: 0.0010
# Epoch 15/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9440 - loss: 0.1809
# Epoch 15: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9492 - loss: 0.1636 - val_categorical_accuracy: 0.9245 - val_loss: 0.2541 - learning_rate: 0.0010
# Epoch 16/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9411 - loss: 0.1501
# Epoch 16: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - categorical_accuracy: 0.9476 - loss: 0.1478 - val_categorical_accuracy: 0.9300 - val_loss: 0.2783 - learning_rate: 0.0010
# Epoch 17/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9517 - loss: 0.1503
# Epoch 17: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9480 - loss: 0.1581 - val_categorical_accuracy: 0.9089 - val_loss: 0.2733 - learning_rate: 0.0010
# Epoch 18/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9443 - loss: 0.1529
# Epoch 18: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - categorical_accuracy: 0.9495 - loss: 0.1458 - val_categorical_accuracy: 0.9205 - val_loss: 0.2604 - learning_rate: 0.0010
# Epoch 19/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9427 - loss: 0.1725
# Epoch 19: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9466 - loss: 0.1613 - val_categorical_accuracy: 0.9021 - val_loss: 0.2937 - learning_rate: 0.0010
# Epoch 20/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9602 - loss: 0.1323
# Epoch 20: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - categorical_accuracy: 0.9529 - loss: 0.1377 - val_categorical_accuracy: 0.8980 - val_loss: 0.3991 - learning_rate: 0.0010
# Epoch 21/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9499 - loss: 0.1551
# Epoch 21: val_categorical_accuracy did not improve from 0.94018
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9515 - loss: 0.1536 - val_categorical_accuracy: 0.9259 - val_loss: 0.3410 - learning_rate: 0.0010
# Epoch 22/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9631 - loss: 0.1195
# Epoch 22: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - categorical_accuracy: 0.9589 - loss: 0.1231 - val_categorical_accuracy: 0.9225 - val_loss: 0.2591 - learning_rate: 2.0000e-04
# Epoch 23/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9574 - loss: 0.1223
# Epoch 23: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9570 - loss: 0.1201 - val_categorical_accuracy: 0.9395 - val_loss: 0.2600 - learning_rate: 2.0000e-04
# Epoch 24/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9588 - loss: 0.1171
# Epoch 24: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - categorical_accuracy: 0.9606 - loss: 0.1112 - val_categorical_accuracy: 0.9286 - val_loss: 0.2592 - learning_rate: 2.0000e-04
# Epoch 25/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9525 - loss: 0.1116
# Epoch 25: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - categorical_accuracy: 0.9565 - loss: 0.1079 - val_categorical_accuracy: 0.9252 - val_loss: 0.2645 - learning_rate: 2.0000e-04
# Epoch 26/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9584 - loss: 0.1062
# Epoch 26: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - categorical_accuracy: 0.9619 - loss: 0.1036 - val_categorical_accuracy: 0.9313 - val_loss: 0.2756 - learning_rate: 2.0000e-04
# Epoch 27/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9625 - loss: 0.1038
# Epoch 27: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - categorical_accuracy: 0.9612 - loss: 0.1058 - val_categorical_accuracy: 0.9320 - val_loss: 0.2360 - learning_rate: 2.0000e-04
# Epoch 28/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9590 - loss: 0.1070
# Epoch 28: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9621 - loss: 0.1039 - val_categorical_accuracy: 0.9347 - val_loss: 0.2308 - learning_rate: 2.0000e-04
# Epoch 29/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9666 - loss: 0.0914
# Epoch 29: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - categorical_accuracy: 0.9619 - loss: 0.0980 - val_categorical_accuracy: 0.9402 - val_loss: 0.2555 - learning_rate: 2.0000e-04
# Epoch 30/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9642 - loss: 0.0971
# Epoch 30: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9628 - loss: 0.0998 - val_categorical_accuracy: 0.9347 - val_loss: 0.2476 - learning_rate: 2.0000e-04
# Epoch 31/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9605 - loss: 0.1045
# Epoch 31: val_categorical_accuracy did not improve from 0.94018
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - categorical_accuracy: 0.9609 - loss: 0.1013 - val_categorical_accuracy: 0.9395 - val_loss: 0.2285 - learning_rate: 2.0000e-04
# Epoch 32/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9631 - loss: 0.0972
# Epoch 32: val_categorical_accuracy improved from 0.94018 to 0.94969, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 32: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9650 - loss: 0.0927 - val_categorical_accuracy: 0.9497 - val_loss: 0.2057 - learning_rate: 2.0000e-04
# Epoch 33/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9583 - loss: 0.1040
# Epoch 33: val_categorical_accuracy did not improve from 0.94969
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - categorical_accuracy: 0.9623 - loss: 0.0951 - val_categorical_accuracy: 0.9381 - val_loss: 0.2458 - learning_rate: 2.0000e-04
# Epoch 34/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9662 - loss: 0.0908
# Epoch 34: val_categorical_accuracy did not improve from 0.94969
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9657 - loss: 0.0908 - val_categorical_accuracy: 0.9422 - val_loss: 0.2412 - learning_rate: 2.0000e-04
# Epoch 35/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9611 - loss: 0.0915
# Epoch 35: val_categorical_accuracy did not improve from 0.94969
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - categorical_accuracy: 0.9617 - loss: 0.0918 - val_categorical_accuracy: 0.9456 - val_loss: 0.2189 - learning_rate: 2.0000e-04
# Epoch 36/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9621 - loss: 0.0995
# Epoch 36: val_categorical_accuracy did not improve from 0.94969
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - categorical_accuracy: 0.9631 - loss: 0.0967 - val_categorical_accuracy: 0.9449 - val_loss: 0.2384 - learning_rate: 2.0000e-04
# Epoch 37/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9627 - loss: 0.0917
# Epoch 37: val_categorical_accuracy did not improve from 0.94969
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - categorical_accuracy: 0.9604 - loss: 0.0951 - val_categorical_accuracy: 0.9436 - val_loss: 0.2491 - learning_rate: 2.0000e-04
# Epoch 38/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9638 - loss: 0.0989
# Epoch 38: val_categorical_accuracy did not improve from 0.94969
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - categorical_accuracy: 0.9663 - loss: 0.0910 - val_categorical_accuracy: 0.9320 - val_loss: 0.2395 - learning_rate: 2.0000e-04
# Epoch 39/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9637 - loss: 0.0912
# Epoch 39: val_categorical_accuracy did not improve from 0.94969
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - categorical_accuracy: 0.9658 - loss: 0.0902 - val_categorical_accuracy: 0.9347 - val_loss: 0.2369 - learning_rate: 2.0000e-04
# Epoch 40/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9679 - loss: 0.0855
# Epoch 40: val_categorical_accuracy did not improve from 0.94969
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9670 - loss: 0.0874 - val_categorical_accuracy: 0.9483 - val_loss: 0.2387 - learning_rate: 2.0000e-04
# Epoch 41/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9642 - loss: 0.0849
# Epoch 41: val_categorical_accuracy improved from 0.94969 to 0.95173, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 41: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - categorical_accuracy: 0.9694 - loss: 0.0829 - val_categorical_accuracy: 0.9517 - val_loss: 0.2250 - learning_rate: 4.0000e-05
# Epoch 42/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9678 - loss: 0.0793
# Epoch 42: val_categorical_accuracy did not improve from 0.95173
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - categorical_accuracy: 0.9675 - loss: 0.0798 - val_categorical_accuracy: 0.9470 - val_loss: 0.2330 - learning_rate: 4.0000e-05
# Epoch 43/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9682 - loss: 0.0828
# Epoch 43: val_categorical_accuracy improved from 0.95173 to 0.95309, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 43: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - categorical_accuracy: 0.9697 - loss: 0.0794 - val_categorical_accuracy: 0.9531 - val_loss: 0.2243 - learning_rate: 4.0000e-05
# Epoch 44/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9652 - loss: 0.0863
# Epoch 44: val_categorical_accuracy did not improve from 0.95309
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - categorical_accuracy: 0.9689 - loss: 0.0818 - val_categorical_accuracy: 0.9524 - val_loss: 0.2220 - learning_rate: 4.0000e-05
# Epoch 45/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9632 - loss: 0.0840
# Epoch 45: val_categorical_accuracy did not improve from 0.95309
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9691 - loss: 0.0774 - val_categorical_accuracy: 0.9517 - val_loss: 0.2371 - learning_rate: 4.0000e-05
# Epoch 46/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9703 - loss: 0.0775
# Epoch 46: val_categorical_accuracy did not improve from 0.95309
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - categorical_accuracy: 0.9714 - loss: 0.0771 - val_categorical_accuracy: 0.9517 - val_loss: 0.2204 - learning_rate: 4.0000e-05
# Epoch 47/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9759 - loss: 0.0707
# Epoch 47: val_categorical_accuracy did not improve from 0.95309
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9747 - loss: 0.0739 - val_categorical_accuracy: 0.9524 - val_loss: 0.2160 - learning_rate: 4.0000e-05
# Epoch 48/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9745 - loss: 0.0748
# Epoch 48: val_categorical_accuracy improved from 0.95309 to 0.95445, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 48: finished saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1e-05.
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - categorical_accuracy: 0.9743 - loss: 0.0729 - val_categorical_accuracy: 0.9545 - val_loss: 0.2181 - learning_rate: 4.0000e-05
# Epoch 49/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9736 - loss: 0.0719
# Epoch 49: val_categorical_accuracy did not improve from 0.95445
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9723 - loss: 0.0717 - val_categorical_accuracy: 0.9545 - val_loss: 0.2198 - learning_rate: 1.0000e-05
# Epoch 50/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9751 - loss: 0.0698
# Epoch 50: val_categorical_accuracy did not improve from 0.95445
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - categorical_accuracy: 0.9721 - loss: 0.0743 - val_categorical_accuracy: 0.9531 - val_loss: 0.2094 - learning_rate: 1.0000e-05
# Epoch 51/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9740 - loss: 0.0691
# Epoch 51: val_categorical_accuracy did not improve from 0.95445
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - categorical_accuracy: 0.9719 - loss: 0.0731 - val_categorical_accuracy: 0.9538 - val_loss: 0.2068 - learning_rate: 1.0000e-05
# Epoch 52/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9774 - loss: 0.0671
# Epoch 52: val_categorical_accuracy did not improve from 0.95445
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - categorical_accuracy: 0.9759 - loss: 0.0685 - val_categorical_accuracy: 0.9545 - val_loss: 0.2141 - learning_rate: 1.0000e-05
# Epoch 53/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9736 - loss: 0.0698
# Epoch 53: val_categorical_accuracy improved from 0.95445 to 0.95513, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 53: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - categorical_accuracy: 0.9755 - loss: 0.0663 - val_categorical_accuracy: 0.9551 - val_loss: 0.2201 - learning_rate: 1.0000e-05
# Epoch 54/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9743 - loss: 0.0690
# Epoch 54: val_categorical_accuracy did not improve from 0.95513
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9738 - loss: 0.0693 - val_categorical_accuracy: 0.9538 - val_loss: 0.2154 - learning_rate: 1.0000e-05
# Epoch 55/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9724 - loss: 0.0797
# Epoch 55: val_categorical_accuracy did not improve from 0.95513
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - categorical_accuracy: 0.9738 - loss: 0.0755 - val_categorical_accuracy: 0.9538 - val_loss: 0.2150 - learning_rate: 1.0000e-05
# Epoch 56/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9720 - loss: 0.0711
# Epoch 56: val_categorical_accuracy did not improve from 0.95513
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - categorical_accuracy: 0.9718 - loss: 0.0718 - val_categorical_accuracy: 0.9531 - val_loss: 0.2168 - learning_rate: 1.0000e-05
# Epoch 57/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9740 - loss: 0.0684
# Epoch 57: val_categorical_accuracy did not improve from 0.95513
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - categorical_accuracy: 0.9718 - loss: 0.0722 - val_categorical_accuracy: 0.9531 - val_loss: 0.2150 - learning_rate: 1.0000e-05
# Epoch 58/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9743 - loss: 0.0691
# Epoch 58: val_categorical_accuracy did not improve from 0.95513
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9726 - loss: 0.0718 - val_categorical_accuracy: 0.9545 - val_loss: 0.2169 - learning_rate: 1.0000e-05
# Epoch 59/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.9753 - loss: 0.0661
# Epoch 59: val_categorical_accuracy did not improve from 0.95513
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - categorical_accuracy: 0.9750 - loss: 0.0671 - val_categorical_accuracy: 0.9538 - val_loss: 0.2142 - learning_rate: 1.0000e-05
# Epoch 60/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9757 - loss: 0.0645
# Epoch 60: val_categorical_accuracy did not improve from 0.95513
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - categorical_accuracy: 0.9740 - loss: 0.0659 - val_categorical_accuracy: 0.9545 - val_loss: 0.2181 - learning_rate: 1.0000e-05
# Epoch 61/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9724 - loss: 0.0714
# Epoch 61: val_categorical_accuracy did not improve from 0.95513
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - categorical_accuracy: 0.9736 - loss: 0.0701 - val_categorical_accuracy: 0.9551 - val_loss: 0.2137 - learning_rate: 1.0000e-05
# Epoch 62/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9735 - loss: 0.0739
# Epoch 62: val_categorical_accuracy did not improve from 0.95513
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - categorical_accuracy: 0.9748 - loss: 0.0728 - val_categorical_accuracy: 0.9538 - val_loss: 0.2174 - learning_rate: 1.0000e-05
# Epoch 63/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9742 - loss: 0.0722
# Epoch 63: val_categorical_accuracy did not improve from 0.95513
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - categorical_accuracy: 0.9735 - loss: 0.0718 - val_categorical_accuracy: 0.9545 - val_loss: 0.2138 - learning_rate: 1.0000e-05
# Epoch 64/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9739 - loss: 0.0681
# Epoch 64: val_categorical_accuracy improved from 0.95513 to 0.95649, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 64: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - categorical_accuracy: 0.9730 - loss: 0.0697 - val_categorical_accuracy: 0.9565 - val_loss: 0.2111 - learning_rate: 1.0000e-05
# Epoch 65/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9747 - loss: 0.0690
# Epoch 65: val_categorical_accuracy did not improve from 0.95649
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - categorical_accuracy: 0.9733 - loss: 0.0686 - val_categorical_accuracy: 0.9551 - val_loss: 0.2212 - learning_rate: 1.0000e-05
# Epoch 66/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9789 - loss: 0.0641
# Epoch 66: val_categorical_accuracy did not improve from 0.95649
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9755 - loss: 0.0683 - val_categorical_accuracy: 0.9558 - val_loss: 0.2160 - learning_rate: 1.0000e-05
# Epoch 67/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9786 - loss: 0.0645
# Epoch 67: val_categorical_accuracy did not improve from 0.95649
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - categorical_accuracy: 0.9791 - loss: 0.0631 - val_categorical_accuracy: 0.9565 - val_loss: 0.2165 - learning_rate: 1.0000e-05
# Epoch 68/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9753 - loss: 0.0662
# Epoch 68: val_categorical_accuracy did not improve from 0.95649
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - categorical_accuracy: 0.9753 - loss: 0.0686 - val_categorical_accuracy: 0.9551 - val_loss: 0.2172 - learning_rate: 1.0000e-05
# Epoch 69/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9770 - loss: 0.0636
# Epoch 69: val_categorical_accuracy did not improve from 0.95649
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - categorical_accuracy: 0.9743 - loss: 0.0700 - val_categorical_accuracy: 0.9545 - val_loss: 0.2174 - learning_rate: 1.0000e-05
# Epoch 70/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9768 - loss: 0.0654
# Epoch 70: val_categorical_accuracy did not improve from 0.95649
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - categorical_accuracy: 0.9752 - loss: 0.0674 - val_categorical_accuracy: 0.9551 - val_loss: 0.2165 - learning_rate: 1.0000e-05
# Epoch 71/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9768 - loss: 0.0648
# Epoch 71: val_categorical_accuracy did not improve from 0.95649
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - categorical_accuracy: 0.9764 - loss: 0.0649 - val_categorical_accuracy: 0.9565 - val_loss: 0.2139 - learning_rate: 1.0000e-05
# Epoch 72/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9731 - loss: 0.0673
# Epoch 72: val_categorical_accuracy improved from 0.95649 to 0.95785, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 72: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9738 - loss: 0.0697 - val_categorical_accuracy: 0.9579 - val_loss: 0.2071 - learning_rate: 1.0000e-05
# Epoch 73/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9770 - loss: 0.0680
# Epoch 73: val_categorical_accuracy improved from 0.95785 to 0.95853, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 73: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - categorical_accuracy: 0.9755 - loss: 0.0649 - val_categorical_accuracy: 0.9585 - val_loss: 0.2047 - learning_rate: 1.0000e-05
# Epoch 74/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9737 - loss: 0.0721
# Epoch 74: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - categorical_accuracy: 0.9748 - loss: 0.0700 - val_categorical_accuracy: 0.9558 - val_loss: 0.2081 - learning_rate: 1.0000e-05
# Epoch 75/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9737 - loss: 0.0716
# Epoch 75: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - categorical_accuracy: 0.9738 - loss: 0.0727 - val_categorical_accuracy: 0.9545 - val_loss: 0.2103 - learning_rate: 1.0000e-05
# Epoch 76/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9795 - loss: 0.0612
# Epoch 76: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - categorical_accuracy: 0.9777 - loss: 0.0650 - val_categorical_accuracy: 0.9551 - val_loss: 0.2111 - learning_rate: 1.0000e-05
# Epoch 77/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9760 - loss: 0.0687
# Epoch 77: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9762 - loss: 0.0680 - val_categorical_accuracy: 0.9585 - val_loss: 0.2134 - learning_rate: 1.0000e-05
# Epoch 78/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9764 - loss: 0.0624
# Epoch 78: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - categorical_accuracy: 0.9750 - loss: 0.0664 - val_categorical_accuracy: 0.9572 - val_loss: 0.2140 - learning_rate: 1.0000e-05
# Epoch 79/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9767 - loss: 0.0678
# Epoch 79: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - categorical_accuracy: 0.9765 - loss: 0.0660 - val_categorical_accuracy: 0.9572 - val_loss: 0.2133 - learning_rate: 1.0000e-05
# Epoch 80/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9716 - loss: 0.0679
# Epoch 80: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - categorical_accuracy: 0.9742 - loss: 0.0661 - val_categorical_accuracy: 0.9572 - val_loss: 0.2196 - learning_rate: 1.0000e-05
# Epoch 81/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9760 - loss: 0.0682
# Epoch 81: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - categorical_accuracy: 0.9782 - loss: 0.0669 - val_categorical_accuracy: 0.9579 - val_loss: 0.2100 - learning_rate: 1.0000e-05
# Epoch 82/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9733 - loss: 0.0822
# Epoch 82: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - categorical_accuracy: 0.9784 - loss: 0.0663 - val_categorical_accuracy: 0.9579 - val_loss: 0.2153 - learning_rate: 1.0000e-05
# Epoch 83/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9762 - loss: 0.0679
# Epoch 83: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9757 - loss: 0.0674 - val_categorical_accuracy: 0.9585 - val_loss: 0.2118 - learning_rate: 1.0000e-05
# Epoch 84/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9732 - loss: 0.0687
# Epoch 84: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - categorical_accuracy: 0.9765 - loss: 0.0647 - val_categorical_accuracy: 0.9565 - val_loss: 0.2180 - learning_rate: 1.0000e-05
# Epoch 85/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9770 - loss: 0.0631
# Epoch 85: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - categorical_accuracy: 0.9760 - loss: 0.0653 - val_categorical_accuracy: 0.9579 - val_loss: 0.2074 - learning_rate: 1.0000e-05
# Epoch 86/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9782 - loss: 0.0633
# Epoch 86: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - categorical_accuracy: 0.9777 - loss: 0.0624 - val_categorical_accuracy: 0.9585 - val_loss: 0.2127 - learning_rate: 1.0000e-05
# Epoch 87/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9776 - loss: 0.0619
# Epoch 87: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - categorical_accuracy: 0.9769 - loss: 0.0648 - val_categorical_accuracy: 0.9579 - val_loss: 0.2072 - learning_rate: 1.0000e-05
# Epoch 88/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9762 - loss: 0.0613
# Epoch 88: val_categorical_accuracy did not improve from 0.95853
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - categorical_accuracy: 0.9764 - loss: 0.0630 - val_categorical_accuracy: 0.9585 - val_loss: 0.2123 - learning_rate: 1.0000e-05
# Epoch 89/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9805 - loss: 0.0585
# Epoch 89: val_categorical_accuracy improved from 0.95853 to 0.95921, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 89: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - categorical_accuracy: 0.9789 - loss: 0.0615 - val_categorical_accuracy: 0.9592 - val_loss: 0.2106 - learning_rate: 1.0000e-05
# Epoch 90/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9807 - loss: 0.0567
# Epoch 90: val_categorical_accuracy did not improve from 0.95921
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - categorical_accuracy: 0.9789 - loss: 0.0615 - val_categorical_accuracy: 0.9592 - val_loss: 0.2178 - learning_rate: 1.0000e-05
# Epoch 91/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9773 - loss: 0.0657
# Epoch 91: val_categorical_accuracy did not improve from 0.95921
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - categorical_accuracy: 0.9784 - loss: 0.0612 - val_categorical_accuracy: 0.9572 - val_loss: 0.2192 - learning_rate: 1.0000e-05
# Epoch 92/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9792 - loss: 0.0576
# Epoch 92: val_categorical_accuracy did not improve from 0.95921
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - categorical_accuracy: 0.9769 - loss: 0.0612 - val_categorical_accuracy: 0.9585 - val_loss: 0.2197 - learning_rate: 1.0000e-05
# Epoch 93/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9824 - loss: 0.0536
# Epoch 93: val_categorical_accuracy did not improve from 0.95921
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - categorical_accuracy: 0.9796 - loss: 0.0606 - val_categorical_accuracy: 0.9579 - val_loss: 0.2161 - learning_rate: 1.0000e-05
# Epoch 94/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.9767 - loss: 0.0647
# Epoch 94: val_categorical_accuracy did not improve from 0.95921
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - categorical_accuracy: 0.9767 - loss: 0.0633 - val_categorical_accuracy: 0.9585 - val_loss: 0.2140 - learning_rate: 1.0000e-05
# Epoch 95/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - categorical_accuracy: 0.9752 - loss: 0.0667
# Epoch 95: val_categorical_accuracy improved from 0.95921 to 0.95989, saving model to UCI_HAR_CNN+GRU_best.keras
#
# Epoch 95: finished saving model to UCI_HAR_CNN+GRU_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9786 - loss: 0.0613 - val_categorical_accuracy: 0.9599 - val_loss: 0.2132 - learning_rate: 1.0000e-05
# Epoch 96/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - categorical_accuracy: 0.9750 - loss: 0.0637
# Epoch 96: val_categorical_accuracy did not improve from 0.95989
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - categorical_accuracy: 0.9765 - loss: 0.0636 - val_categorical_accuracy: 0.9579 - val_loss: 0.2159 - learning_rate: 1.0000e-05
# Epoch 97/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - categorical_accuracy: 0.9780 - loss: 0.0604
# Epoch 97: val_categorical_accuracy did not improve from 0.95989
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - categorical_accuracy: 0.9774 - loss: 0.0642 - val_categorical_accuracy: 0.9565 - val_loss: 0.2104 - learning_rate: 1.0000e-05
# Epoch 98/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9778 - loss: 0.0623
# Epoch 98: val_categorical_accuracy did not improve from 0.95989
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - categorical_accuracy: 0.9753 - loss: 0.0663 - val_categorical_accuracy: 0.9579 - val_loss: 0.2022 - learning_rate: 1.0000e-05
# Epoch 99/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.9783 - loss: 0.0587
# Epoch 99: val_categorical_accuracy did not improve from 0.95989
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - categorical_accuracy: 0.9784 - loss: 0.0594 - val_categorical_accuracy: 0.9579 - val_loss: 0.2110 - learning_rate: 1.0000e-05
# Epoch 100/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.9789 - loss: 0.0595
# Epoch 100: val_categorical_accuracy did not improve from 0.95989
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - categorical_accuracy: 0.9774 - loss: 0.0628 - val_categorical_accuracy: 0.9592 - val_loss: 0.2089 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 95.

# %% [markdown]
# # 모델 평가

# %%
# best 기록 확인
model = tf.keras.models.load_model("UCI_HAR_CNN+GRU_best.keras")

train_loss, train_acc = model.evaluate(X_train, y_train_onehot, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test_onehot, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# Training accuracy: 98.42%
# Training loss: 0.0771
# Test accuracy: 94.64%
# Test loss: 0.2175

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9876    0.9617    0.9745       496
#            1     0.9845    0.9448    0.9642       471
#            2     0.9272    1.0000    0.9622       420
#            3     0.9610    0.8024    0.8746       491
#            4     0.8515    0.9699    0.9069       532
#            5     0.9890    1.0000    0.9944       537
#
#     accuracy                         0.9464      2947
#    macro avg     0.9501    0.9465    0.9461      2947
# weighted avg     0.9497    0.9464    0.9459      2947

# %%
# loss / accuracy 그래프
train_loss = history.history['loss']
train_accuracy = history.history['categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.ylim([0.0, 1.0])
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# 혼동행렬(히트맵)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
