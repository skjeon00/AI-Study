# %% [markdown]
# # **UCI HAR - Resnet**

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers, Input, Model, backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Conv1D, BatchNormalization, ReLU, MaxPooling1D, GlobalAveragePooling1D, Add, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

LABELS = [
    "WALKING",
    "WALKING_UPSTAIRS",
    "WALKING_DOWNSTAIRS",
    "SITTING",
    "STANDING",
    "LAYING"
]

# %%
TRAIN = "train/"
TEST = "test/"

DATASET_PATH = "/content/drive/MyDrive/AI_Study/UCI_HAR_Dataset/"

# %%
# Load "X"
def load_X(X_signals_paths):
    X_signals = []

    for signal_type_path in X_signals_paths:
        series_list = []                                        # 한 센서축 데이터 전체 저장

        with open(signal_type_path, 'r') as file:
            for row in file:
                row_clean = row.replace('  ', ' ')              # 공백 2개를 1개로
                row_clean = row_clean.strip()                   # 양쪽 공백 제거
                serie = row_clean.split(' ')                    # 공백 기준 split
                serie_array = np.array(serie, dtype=np.float32) # float32 numpy 배열로 변환
                series_list.append(serie_array)                 # 시퀀스 추가

        # 하나의 센서축 데이터 추가 (feature)
        X_signals.append(series_list)

    # shape: (특성 수, 샘플 수, 타임스텝 수)
    X_signals = np.array(X_signals)
    # shape 변환 → (샘플 수, 타임스텝 수, 특성 수)
    return np.transpose(X_signals, (1, 2, 0))


X_train_signals_paths = [
    DATASET_PATH + TRAIN + "Inertial_Signals/" + signal + "train.txt"
    for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    DATASET_PATH + TEST + "Inertial_Signals/" + signal + "test.txt"
    for signal in INPUT_SIGNAL_TYPES
]

X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("첫 번째 샘플 데이터:\n", X_train[0])
# Out:
# X_train shape: (7352, 128, 9)
# X_test shape: (2947, 128, 9)
# 첫 번째 샘플 데이터:
#  [[ 1.808515e-04  1.076681e-02  5.556068e-02 ...  1.012817e+00
#   -1.232167e-01  1.029341e-01]
#  [ 1.013856e-02  6.579480e-03  5.512483e-02 ...  1.022833e+00
#   -1.268756e-01  1.056872e-01]
#  [ 9.275574e-03  8.928878e-03  4.840473e-02 ...  1.022028e+00
#   -1.240037e-01  1.021025e-01]
#  ...
#  [-1.147484e-03  1.714439e-04  2.647864e-03 ...  1.018445e+00
#   -1.240696e-01  1.003852e-01]
#  [-2.222655e-04  1.574181e-03  2.381057e-03 ...  1.019372e+00
#   -1.227451e-01  9.987355e-02]
#  [ 1.575500e-03  3.070189e-03 -2.269757e-03 ...  1.021171e+00
#   -1.213260e-01  9.498741e-02]]

# %%
# Load "y"

def load_y(y_path):
    with open(y_path, 'r') as file:
        labels = [int(line.strip()) for line in file]
    # 라벨을 0부터 시작하도록 -1 (원래 라벨이 1부터 시작)
    return np.array(labels, dtype=np.int32) - 1


y_train_path = DATASET_PATH + TRAIN + "y_train.txt"
y_test_path = DATASET_PATH + TEST + "y_test.txt"

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
print(y_train[:5])
# Out:
# y_train shape: (7352,)
# y_test shape: (2947,)
# [4 4 4 4 4]

# %%
# 입력 shape 정의
input_shape = (X_train.shape[1], X_train.shape[2])
num_classes = 6

K.clear_session()

# --- ResNet 블록 정의 ---
def residual_block(x, filters, kernel_size=3, stride=1):
    shortcut = x

    # 첫 번째 Conv 층
    x = Conv1D(filters, kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    # 두 번째 Conv 층
    x = Conv1D(filters, kernel_size, strides=1, padding='same')(x)
    x = BatchNormalization()(x)

    # 차원 맞추기
    if shortcut.shape[-1] != filters or stride != 1:
        shortcut = Conv1D(filters, 1, strides=stride, padding='same')(shortcut)
        shortcut = BatchNormalization()(shortcut)

    # 잔차 연결
    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

# --- 전체 모델 빌딩 ---
inputs = Input(shape=input_shape)

# 초기 특징 추출 (Stem)
x = Conv1D(64, 7, strides=1, padding='same')(inputs)
x = BatchNormalization()(x)
x = ReLU()(x)

# 첫 번째 잔차 블록 구조
x = residual_block(x, filters=128, kernel_size=7)
x = Dropout(0.3)(x)

# 두 번째 잔차 블록 구조 + 맥스풀링으로 압축
x = residual_block(x, filters=256, kernel_size=5)
x = MaxPooling1D(2)(x)
x = Dropout(0.3)(x)

# 세 번째 잔차 블록 구조 + 맥스풀링으로 압축
x = residual_block(x, filters=256, kernel_size=3)
x = MaxPooling1D(2)(x)

# 차원 축소 및 데이터 요약
x = GlobalAveragePooling1D()(x)

# 은닉층 (Dense)
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

# 최종 출력층
outputs = Dense(num_classes, activation='softmax')(x)

# 모델 생성
model = Model(inputs=inputs, outputs=outputs)

# 컴파일 설정
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['sparse_categorical_accuracy']
)

print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 9)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 128, 64)   │      4,096 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 64)   │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 128, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 128, 128)  │     57,472 │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128)  │        512 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 128, 128)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 128, 128)  │    114,816 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 128, 128)  │      8,320 │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128)  │        512 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128)  │        512 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128)  │          0 │ re_lu_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 128, 256)  │    164,096 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 256)  │      1,024 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 256)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 128, 256)  │    327,936 │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 128, 256)  │     33,024 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 256)  │      1,024 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 256)  │      1,024 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128, 256)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 128, 256)  │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 64, 256)   │          0 │ re_lu_4[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 256)   │          0 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 64, 256)   │    196,864 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 256)   │      1,024 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 256)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 64, 256)   │    196,864 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 256)   │      1,024 │ conv1d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 64, 256)   │          0 │ batch_normalizat… │
# │                     │                   │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 64, 256)   │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 32, 256)   │          0 │ re_lu_6[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling1d_1[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │     65,792 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 6)         │      1,542 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,178,758 (4.50 MB)
#  Trainable params: 1,174,790 (4.48 MB)
#  Non-trainable params: 3,968 (15.50 KB)
# None

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_HAR_Resnet_best.keras",
                save_best_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=30,
                verbose=1,
                mode='max',
                restore_best_weights=True
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=8,
                min_lr=0.00001,
                verbose=1
            )
        ]

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=16,
            validation_split=0.2,
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5068 - sparse_categorical_accuracy: 0.8117
# Epoch 1: val_sparse_categorical_accuracy improved from None to 0.77090, saving model to UCI_HAR_Resnet_best.keras
#
# Epoch 1: finished saving model to UCI_HAR_Resnet_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 43s 50ms/step - loss: 0.3532 - sparse_categorical_accuracy: 0.8723 - val_loss: 0.7974 - val_sparse_categorical_accuracy: 0.7709 - learning_rate: 0.0010
# Epoch 2/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2299 - sparse_categorical_accuracy: 0.9175
# Epoch 2: val_sparse_categorical_accuracy improved from 0.77090 to 0.91434, saving model to UCI_HAR_Resnet_best.keras
#
# Epoch 2: finished saving model to UCI_HAR_Resnet_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.2296 - sparse_categorical_accuracy: 0.9153 - val_loss: 0.2280 - val_sparse_categorical_accuracy: 0.9143 - learning_rate: 0.0010
# Epoch 3/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1798 - sparse_categorical_accuracy: 0.9308
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.91434
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1883 - sparse_categorical_accuracy: 0.9252 - val_loss: 0.2446 - val_sparse_categorical_accuracy: 0.8491 - learning_rate: 0.0010
# Epoch 4/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1679 - sparse_categorical_accuracy: 0.9303
# Epoch 4: val_sparse_categorical_accuracy improved from 0.91434 to 0.92182, saving model to UCI_HAR_Resnet_best.keras
#
# Epoch 4: finished saving model to UCI_HAR_Resnet_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1650 - sparse_categorical_accuracy: 0.9328 - val_loss: 0.2492 - val_sparse_categorical_accuracy: 0.9218 - learning_rate: 0.0010
# Epoch 5/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1455 - sparse_categorical_accuracy: 0.9358
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.92182
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1482 - sparse_categorical_accuracy: 0.9371 - val_loss: 0.2146 - val_sparse_categorical_accuracy: 0.9069 - learning_rate: 0.0010
# Epoch 6/100
# 361/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1495 - sparse_categorical_accuracy: 0.9384
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.92182
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1491 - sparse_categorical_accuracy: 0.9361 - val_loss: 0.1994 - val_sparse_categorical_accuracy: 0.9069 - learning_rate: 0.0010
# Epoch 7/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1435 - sparse_categorical_accuracy: 0.9303
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.92182
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1373 - sparse_categorical_accuracy: 0.9362 - val_loss: 0.2747 - val_sparse_categorical_accuracy: 0.8933 - learning_rate: 0.0010
# Epoch 8/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1149 - sparse_categorical_accuracy: 0.9475
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.92182
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1281 - sparse_categorical_accuracy: 0.9417 - val_loss: 0.2115 - val_sparse_categorical_accuracy: 0.9116 - learning_rate: 0.0010
# Epoch 9/100
# 364/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1548 - sparse_categorical_accuracy: 0.9342
# Epoch 9: val_sparse_categorical_accuracy improved from 0.92182 to 0.93610, saving model to UCI_HAR_Resnet_best.keras
#
# Epoch 9: finished saving model to UCI_HAR_Resnet_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.1453 - sparse_categorical_accuracy: 0.9408 - val_loss: 0.1874 - val_sparse_categorical_accuracy: 0.9361 - learning_rate: 0.0010
# Epoch 10/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1276 - sparse_categorical_accuracy: 0.9464
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1209 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.1824 - val_sparse_categorical_accuracy: 0.9279 - learning_rate: 0.0010
# Epoch 11/100
# 363/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1386 - sparse_categorical_accuracy: 0.9387
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1310 - sparse_categorical_accuracy: 0.9415 - val_loss: 0.2245 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 12/100
# 364/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1342 - sparse_categorical_accuracy: 0.9472
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1285 - sparse_categorical_accuracy: 0.9485 - val_loss: 0.1896 - val_sparse_categorical_accuracy: 0.9266 - learning_rate: 0.0010
# Epoch 13/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1195 - sparse_categorical_accuracy: 0.9508
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1223 - sparse_categorical_accuracy: 0.9483 - val_loss: 0.1828 - val_sparse_categorical_accuracy: 0.9239 - learning_rate: 0.0010
# Epoch 14/100
# 361/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1270 - sparse_categorical_accuracy: 0.9468
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1272 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.1932 - val_sparse_categorical_accuracy: 0.9130 - learning_rate: 0.0010
# Epoch 15/100
# 364/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1326 - sparse_categorical_accuracy: 0.9452
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1292 - sparse_categorical_accuracy: 0.9468 - val_loss: 0.1884 - val_sparse_categorical_accuracy: 0.9225 - learning_rate: 0.0010
# Epoch 16/100
# 361/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1371 - sparse_categorical_accuracy: 0.9403
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1322 - sparse_categorical_accuracy: 0.9447 - val_loss: 0.1893 - val_sparse_categorical_accuracy: 0.9313 - learning_rate: 0.0010
# Epoch 17/100
# 364/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1039 - sparse_categorical_accuracy: 0.9531
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1080 - sparse_categorical_accuracy: 0.9519 - val_loss: 0.2074 - val_sparse_categorical_accuracy: 0.9293 - learning_rate: 0.0010
# Epoch 18/100
# 363/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1119 - sparse_categorical_accuracy: 0.9496
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.93610
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1207 - sparse_categorical_accuracy: 0.9475 - val_loss: 0.2105 - val_sparse_categorical_accuracy: 0.9055 - learning_rate: 0.0010
# Epoch 19/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1097 - sparse_categorical_accuracy: 0.9533
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0998 - sparse_categorical_accuracy: 0.9572 - val_loss: 0.1933 - val_sparse_categorical_accuracy: 0.9205 - learning_rate: 2.0000e-04
# Epoch 20/100
# 361/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0967 - sparse_categorical_accuracy: 0.9565
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0983 - sparse_categorical_accuracy: 0.9561 - val_loss: 0.2086 - val_sparse_categorical_accuracy: 0.9300 - learning_rate: 2.0000e-04
# Epoch 21/100
# 362/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0947 - sparse_categorical_accuracy: 0.9597
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0951 - sparse_categorical_accuracy: 0.9589 - val_loss: 0.1972 - val_sparse_categorical_accuracy: 0.9300 - learning_rate: 2.0000e-04
# Epoch 22/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1009 - sparse_categorical_accuracy: 0.9503
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1034 - sparse_categorical_accuracy: 0.9510 - val_loss: 0.1940 - val_sparse_categorical_accuracy: 0.9157 - learning_rate: 2.0000e-04
# Epoch 23/100
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0921 - sparse_categorical_accuracy: 0.9593
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.93610
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0948 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.1914 - val_sparse_categorical_accuracy: 0.9334 - learning_rate: 2.0000e-04
# Epoch 24/100
# 363/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1044 - sparse_categorical_accuracy: 0.9542
# Epoch 24: val_sparse_categorical_accuracy improved from 0.93610 to 0.93950, saving model to UCI_HAR_Resnet_best.keras
#
# Epoch 24: finished saving model to UCI_HAR_Resnet_best.keras
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 0.1002 - sparse_categorical_accuracy: 0.9551 - val_loss: 0.1876 - val_sparse_categorical_accuracy: 0.9395 - learning_rate: 2.0000e-04
# Epoch 25/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0902 - sparse_categorical_accuracy: 0.9612
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0927 - sparse_categorical_accuracy: 0.9602 - val_loss: 0.2272 - val_sparse_categorical_accuracy: 0.9150 - learning_rate: 2.0000e-04
# Epoch 26/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1002 - sparse_categorical_accuracy: 0.9557
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.93950
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0949 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.2141 - val_sparse_categorical_accuracy: 0.9375 - learning_rate: 2.0000e-04
# Epoch 27/100
# 363/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0929 - sparse_categorical_accuracy: 0.9578
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0916 - sparse_categorical_accuracy: 0.9597 - val_loss: 0.2033 - val_sparse_categorical_accuracy: 0.9177 - learning_rate: 4.0000e-05
# Epoch 28/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0880 - sparse_categorical_accuracy: 0.9586
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0867 - sparse_categorical_accuracy: 0.9587 - val_loss: 0.2024 - val_sparse_categorical_accuracy: 0.9225 - learning_rate: 4.0000e-05
# Epoch 29/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0842 - sparse_categorical_accuracy: 0.9580
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0821 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.2002 - val_sparse_categorical_accuracy: 0.9191 - learning_rate: 4.0000e-05
# Epoch 30/100
# 363/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9617
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0842 - sparse_categorical_accuracy: 0.9597 - val_loss: 0.2002 - val_sparse_categorical_accuracy: 0.9184 - learning_rate: 4.0000e-05
# Epoch 31/100
# 364/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0835 - sparse_categorical_accuracy: 0.9640
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0878 - sparse_categorical_accuracy: 0.9612 - val_loss: 0.1969 - val_sparse_categorical_accuracy: 0.9184 - learning_rate: 4.0000e-05
# Epoch 32/100
# 363/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0859 - sparse_categorical_accuracy: 0.9602
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0825 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.1992 - val_sparse_categorical_accuracy: 0.9205 - learning_rate: 4.0000e-05
# Epoch 33/100
# 364/368 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0812 - sparse_categorical_accuracy: 0.9595
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0817 - sparse_categorical_accuracy: 0.9606 - val_loss: 0.2004 - val_sparse_categorical_accuracy: 0.9245 - learning_rate: 4.0000e-05
# Epoch 34/100
# 361/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0858 - sparse_categorical_accuracy: 0.9551
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.93950
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-05.
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0820 - sparse_categorical_accuracy: 0.9602 - val_loss: 0.2035 - val_sparse_categorical_accuracy: 0.9184 - learning_rate: 4.0000e-05
# Epoch 35/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0746 - sparse_categorical_accuracy: 0.9639
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0800 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.1976 - val_sparse_categorical_accuracy: 0.9191 - learning_rate: 1.0000e-05
# Epoch 36/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0768 - sparse_categorical_accuracy: 0.9640
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0788 - sparse_categorical_accuracy: 0.9629 - val_loss: 0.1943 - val_sparse_categorical_accuracy: 0.9191 - learning_rate: 1.0000e-05
# Epoch 37/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0834 - sparse_categorical_accuracy: 0.9602
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0817 - sparse_categorical_accuracy: 0.9617 - val_loss: 0.1974 - val_sparse_categorical_accuracy: 0.9191 - learning_rate: 1.0000e-05
# Epoch 38/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0835 - sparse_categorical_accuracy: 0.9599
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9640 - val_loss: 0.1942 - val_sparse_categorical_accuracy: 0.9205 - learning_rate: 1.0000e-05
# Epoch 39/100
# 362/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0899 - sparse_categorical_accuracy: 0.9588
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0838 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.1960 - val_sparse_categorical_accuracy: 0.9191 - learning_rate: 1.0000e-05
# Epoch 40/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0756 - sparse_categorical_accuracy: 0.9646
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0779 - sparse_categorical_accuracy: 0.9638 - val_loss: 0.1942 - val_sparse_categorical_accuracy: 0.9191 - learning_rate: 1.0000e-05
# Epoch 41/100
# 362/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0717 - sparse_categorical_accuracy: 0.9684
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0791 - sparse_categorical_accuracy: 0.9629 - val_loss: 0.1940 - val_sparse_categorical_accuracy: 0.9198 - learning_rate: 1.0000e-05
# Epoch 42/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0841 - sparse_categorical_accuracy: 0.9590
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0803 - sparse_categorical_accuracy: 0.9619 - val_loss: 0.1992 - val_sparse_categorical_accuracy: 0.9191 - learning_rate: 1.0000e-05
# Epoch 43/100
# 364/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0671 - sparse_categorical_accuracy: 0.9683
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0742 - sparse_categorical_accuracy: 0.9655 - val_loss: 0.1938 - val_sparse_categorical_accuracy: 0.9198 - learning_rate: 1.0000e-05
# Epoch 44/100
# 363/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0972 - sparse_categorical_accuracy: 0.9579
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0837 - sparse_categorical_accuracy: 0.9624 - val_loss: 0.1986 - val_sparse_categorical_accuracy: 0.9191 - learning_rate: 1.0000e-05
# Epoch 45/100
# 363/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0740 - sparse_categorical_accuracy: 0.9654
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0795 - sparse_categorical_accuracy: 0.9633 - val_loss: 0.1900 - val_sparse_categorical_accuracy: 0.9239 - learning_rate: 1.0000e-05
# Epoch 46/100
# 364/368 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0717 - sparse_categorical_accuracy: 0.9657
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0752 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.1949 - val_sparse_categorical_accuracy: 0.9198 - learning_rate: 1.0000e-05
# Epoch 47/100
# 362/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0745 - sparse_categorical_accuracy: 0.9653
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0768 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.1919 - val_sparse_categorical_accuracy: 0.9218 - learning_rate: 1.0000e-05
# Epoch 48/100
# 364/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0761 - sparse_categorical_accuracy: 0.9621
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0802 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.1990 - val_sparse_categorical_accuracy: 0.9198 - learning_rate: 1.0000e-05
# Epoch 49/100
# 363/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0817 - sparse_categorical_accuracy: 0.9598
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0759 - sparse_categorical_accuracy: 0.9623 - val_loss: 0.2021 - val_sparse_categorical_accuracy: 0.9198 - learning_rate: 1.0000e-05
# Epoch 50/100
# 364/368 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0747 - sparse_categorical_accuracy: 0.9628
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0805 - sparse_categorical_accuracy: 0.9616 - val_loss: 0.1986 - val_sparse_categorical_accuracy: 0.9198 - learning_rate: 1.0000e-05
# Epoch 51/100
# 365/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0788 - sparse_categorical_accuracy: 0.9615
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0759 - sparse_categorical_accuracy: 0.9636 - val_loss: 0.2030 - val_sparse_categorical_accuracy: 0.9198 - learning_rate: 1.0000e-05
# Epoch 52/100
# 366/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0831 - sparse_categorical_accuracy: 0.9638
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0808 - sparse_categorical_accuracy: 0.9638 - val_loss: 0.2056 - val_sparse_categorical_accuracy: 0.9198 - learning_rate: 1.0000e-05
# Epoch 53/100
# 367/368 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0787 - sparse_categorical_accuracy: 0.9662
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0804 - sparse_categorical_accuracy: 0.9643 - val_loss: 0.2009 - val_sparse_categorical_accuracy: 0.9205 - learning_rate: 1.0000e-05
# Epoch 54/100
# 363/368 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0870 - sparse_categorical_accuracy: 0.9587
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.93950
# 368/368 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0787 - sparse_categorical_accuracy: 0.9624 - val_loss: 0.2036 - val_sparse_categorical_accuracy: 0.9198 - learning_rate: 1.0000e-05
# Epoch 54: early stopping
# Restoring model weights from the end of the best epoch: 24.

# %%
# best 기록 확인
model = tf.keras.models.load_model("UCI_HAR_Resnet_best.keras")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# Training accuracy: 95.89%
# Training loss: 0.1125
# Test accuracy: 92.91%
# Test loss: 0.1910

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9617    0.9805       496
#            1     0.9758    0.9406    0.9578       471
#            2     1.0000    0.9690    0.9843       420
#            3     0.7726    0.8513    0.8101       491
#            4     0.8669    0.8571    0.8620       532
#            5     0.9908    1.0000    0.9954       537
#
#     accuracy                         0.9291      2947
#    macro avg     0.9344    0.9300    0.9317      2947
# weighted avg     0.9325    0.9291    0.9303      2947

# %%
# loss / accuracy 그래프
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss (Main)')
plt.plot(val_loss, 'b', label='Validation loss (Main)')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.ylim([0.5, 1.0])
plt.plot(train_accuracy, 'r', label='Training Accuracy (Main)')
plt.plot(val_accuracy, 'b', label='Validation Accuracy (Main)')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# 혼동행렬(히트맵)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
