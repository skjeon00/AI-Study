# %% [markdown]
# # **Wild SHARD - CNN**

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers, Input, Model, backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Conv1D, BatchNormalization, ReLU, MaxPooling1D, GlobalAveragePooling1D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/AI_assignment/Wild_SHARD_Dataset/wild_shard_data.csv.csv')

# %% [markdown]
# # Dataset Info
# - Dataset의 양, 상태, 타입을 파악해서 어떤 전처리가 필요한지 확인
#   - 데이터 규모 : 약 48만개의 데이터 수
#   - 칼럼(Feature) : 총 17개의 column (각 센서들(자이로, 가속도, 중력, 회전 등)를 방향(XYZ)별로 기록)
#   - 결측치 여부 : 모든 컬럼의 'Non-Null Count'가 행의 총개수와 일치하는지 확인 > 결측치 없음
#   - 데이터 타입 : 센서 값들이 float64로 되어있어 정규화가 즉시 가능한지 확인 + 'activity'가 object 타입임을 확인 > 라벨인코더 필요

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483895 entries, 0 to 483894
# Data columns (total 17 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   AG-X       483895 non-null  float64
#  1   AG-Y       483895 non-null  float64
#  2   AG-Z       483895 non-null  float64
#  3   Acc-X      483895 non-null  float64
#  4   Acc-Y      483895 non-null  float64
#  5   Acc-Z      483895 non-null  float64
#  6   Gravity-X  483895 non-null  float64
#  7   Gravity-Y  483895 non-null  float64
#  8   Gravity-Z  483895 non-null  float64
#  9   RR-X       483895 non-null  float64
#  10  RR-Y       483895 non-null  float64
#  11  RR-Z       483895 non-null  float64
#  12  RV-X       483895 non-null  float64
#  13  RV-Y       483895 non-null  float64
#  14  RV-Z       483895 non-null  float64
#  15  cos        483895 non-null  float64
#  16  activity   483895 non-null  object
# dtypes: float64(16), object(1)
# memory usage: 62.8+ MB

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# **Label 재정의**
# - Label Encoder

# %%
# 'activity'라벨명 확인 (중복제거)
print(df['activity'].unique())
# Out:
# ['Downstairs' 'Running' 'Sitting' 'Standing' 'Upstairs' 'Walking']

# %%
# 라벨인코더 : 'activity'(라벨명)이 문자열로 되어있어 숫자로 변환
le = LabelEncoder()
df['activity'] = le.fit_transform(df['activity'])
print(df['activity'].value_counts())
# Out:
# activity
# 5    90194
# 2    86574
# 1    80447
# 3    79947
# 4    74302
# 0    72431
# Name: count, dtype: int64

# %%
LABELS = ['Downstairs', 'Running', 'Sitting', 'Standing', 'Upstairs', 'Walking']

# %% [markdown]
# **Feature Selection**
# - 가속도, 자이로 센서 값만 사용하기 위해 나머지 칼럼 제거

# %%
df = df.drop(columns=['Gravity-X', 'Gravity-Y', 'Gravity-Z',
                      'RR-X', 'RR-Y', 'RR-Z',
                      'RV-X', 'RV-Y', 'RV-Z', 'cos'])

# %% [markdown]
# **Feature Scaling**
# - Normalization (정규화) : feature 간의 값의 단위가 달라 모델이 편향되지 않도록 '평균 0, 표준편차 1'로 맞춰주는 작업
#   - Why? 두 센서의 변동 폭이 다르기 때문에, 정규화하지 않으면 상대적으로 변동 폭이 큰 자이로에 과도하게 가중치를 부여할 수 있음.
#   - So, 정규화를 통해 모델이 가속도처럼 미세한 진동 패턴도 잘 감지하게끔 하여 정확도를 향상시킴.
# - 추가로, 약 48만 개의 대량 데이터이므로, 스케일링이 학습 속도를 높여줄 수 있음.

# %% [markdown]
# - 두 칼럼의 값 범위 시각화
#   - 가속도(Acc): 박스(데이터의 몸통 부분)가 매우 납작하게 붙어 있음. 즉, 대부분의 데이터가 0 근처에 아주 촘촘하게 모여있다는 것.
#   - 자이로(AG): 가속도에 비해 박스의 두께가 상대적으로 두꺼움. 이는 대부분 움직임의 변동 폭이 가속도보다 훨씬 크다는 것.

# %%
sensor_cols = ['Acc-X', 'Acc-Y', 'Acc-Z', 'AG-X', 'AG-Y', 'AG-Z']

plt.figure(figsize=(12, 6))
sns.boxplot(data=df[sensor_cols])
plt.title('Comparison of Sensor Scales (Before Scaling)', fontsize=15)
plt.ylabel('Value')
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# 학습에 사용할 센서 컬럼들 선택
features = ['Acc-X', 'Acc-Y', 'Acc-Z', 'AG-X', 'AG-Y', 'AG-Z']
X = df[features]
y = df['activity']

# 정규화
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 다시 데이터프레임 형태로 변환 (Sliding Window을 위해)
df_scaled = pd.DataFrame(X_scaled, columns=features)
df_scaled['activity'] = y.values

# %% [markdown]
# **Sliding Window**
# - 모델에게 "이 128개의 연속된 움직임이 무슨 행동인지 맞춰봐"라고 가르치기 위해 데이터를 묶음(윈도우)으로 슬라이딩하는 작업
# - Why?
#   - Wild-SHARD data는 UCI HAR과 달리 window가 없는 일명 통짜 데이터셋임.
#   - but, CNN은 1개의 행이 아니라, 일정 시간 동안의 '이미지' 같은 데이터를 입력으로 받기 때문에 슬라이싱 필요.
# - 50%씩 overlap하는 이유 : 동작을 특정하는 데 있어 중요한 동작이 윈도우를 자르는 선에 걸려서 정보가 손실되는 것을 방지하기 위해.

# %%
# 윈도우 생성 함수
def create_windows(data, window_size, step_size):
    segments = []
    labels = []
    for i in range(0, len(data) - window_size, step_size):
        # 윈도우 크기만큼 데이터 추출
        window = data.iloc[i:i + window_size][features].values
        # 해당 윈도우의 최빈값(가장 많이 나온 라벨)을 정답으로 선택
        label = data.iloc[i:i + window_size]['activity'].mode()[0]
        segments.append(window)
        labels.append(label)
    return np.array(segments), np.array(labels)

# 윈도우 사이즈 128(약 2.56초만큼의 데이터), 50% 중첩(step_size=50)
X_windows, y_windows = create_windows(df_scaled, window_size=128, step_size=50)

print(f"최종 데이터 형태: {X_windows.shape}")
# Out:
# 최종 데이터 형태: (9676, 128, 6)

# %% [markdown]
# 학습/검증 데이터 분리

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_windows, y_windows, test_size=0.2, random_state=42, stratify=y_windows)

# %% [markdown]
# 학습 전 최종 Data Shape 확인

# %%
# X_train, X_test
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (7740, 128, 6)
# X_test shape: (1936, 128, 6)

# %%
# 정답(라벨) 데이터를 원-핫 인코딩으로 변환
y_train_onehot = to_categorical(y_train)
y_test_onehot = to_categorical(y_test)

# y_train, y_test
print("y_train shape:", y_train_onehot.shape)
print("y_test shape:", y_test_onehot.shape)
print(y_train[:5])
# Out:
# y_train shape: (7740, 6)
# y_test shape: (1936, 6)
# [0 1 4 1 4]

# %% [markdown]
# # Model Building

# %%
input_shape = (X_train.shape[1], X_train.shape[2])
num_classes = 6

K.clear_session()

model = Sequential([
    Input(shape=input_shape),

    # 첫 번째 특징 추출
    Conv1D(128, 7, padding='same'),
    BatchNormalization(),
    ReLU(),

    # 두 번째 특징 추출 (+ MaxPooling으로 압축)
    Conv1D(256, 5, padding='same'),
    BatchNormalization(),
    ReLU(),
    MaxPooling1D(2),
    Dropout(0.3),

    # 세 번째 특징 추출
    Conv1D(256, 5, padding='same'),
    BatchNormalization(),
    ReLU(),

    # 네 번째 특징 추출 (+ MaxPooling으로 압축)
    Conv1D(256, 3, padding='same'),
    BatchNormalization(),
    ReLU(),
    MaxPooling1D(2),

    # 차원 축소 및 데이터 요약 : 1차원 벡터
    GlobalAveragePooling1D(),

    # 추출된 특징들을 조합하는 은닉층
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    # 최종적으로 6가지 행동 중 하나를 결정하는 출력 층
    Dense(num_classes, activation='softmax')
])

# 컴파일 설정
model.compile(
            optimizer='adam',
            loss='categorical_crossentropy',
            metrics=['categorical_accuracy']
        )

print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 128, 128)       │         5,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 128, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 128, 256)       │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 128, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 64, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 64, 256)        │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 64, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 64, 256)        │       196,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 64, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 32, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │         1,542 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 766,342 (2.92 MB)
#  Trainable params: 764,038 (2.91 MB)
#  Non-trainable params: 2,304 (9.00 KB)
# None

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# callbacks

# %%
callbacks = [
            ModelCheckpoint(
                "Wild_CNN_best.keras",
                save_best_only=True,
                monitor="val_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_categorical_accuracy",
                patience=35,
                verbose=1,
                mode='max',
                restore_best_weights=True
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=10,
                min_lr=0.00001,
                verbose=1
            )
        ]

# %% [markdown]
# # Model Training

# %%
history = model.fit(
            X_train, y_train_onehot,
            epochs=200,
            batch_size=32,
            validation_split=0.2,
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/200
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.6201 - loss: 1.1407
# Epoch 1: val_categorical_accuracy improved from None to 0.70672, saving model to Wild_CNN_best.keras
#
# Epoch 1: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 54ms/step - categorical_accuracy: 0.7022 - loss: 0.8797 - val_categorical_accuracy: 0.7067 - val_loss: 0.7817 - learning_rate: 0.0010
# Epoch 2/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8028 - loss: 0.5788
# Epoch 2: val_categorical_accuracy improved from 0.70672 to 0.86047, saving model to Wild_CNN_best.keras
#
# Epoch 2: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - categorical_accuracy: 0.8068 - loss: 0.5668 - val_categorical_accuracy: 0.8605 - val_loss: 0.4734 - learning_rate: 0.0010
# Epoch 3/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8387 - loss: 0.4833
# Epoch 3: val_categorical_accuracy improved from 0.86047 to 0.86176, saving model to Wild_CNN_best.keras
#
# Epoch 3: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - categorical_accuracy: 0.8448 - loss: 0.4656 - val_categorical_accuracy: 0.8618 - val_loss: 0.4190 - learning_rate: 0.0010
# Epoch 4/200
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8737 - loss: 0.3780
# Epoch 4: val_categorical_accuracy improved from 0.86176 to 0.90245, saving model to Wild_CNN_best.keras
#
# Epoch 4: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.8729 - loss: 0.3824 - val_categorical_accuracy: 0.9025 - val_loss: 0.3374 - learning_rate: 0.0010
# Epoch 5/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.8763 - loss: 0.3831
# Epoch 5: val_categorical_accuracy improved from 0.90245 to 0.91085, saving model to Wild_CNN_best.keras
#
# Epoch 5: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - categorical_accuracy: 0.8753 - loss: 0.3746 - val_categorical_accuracy: 0.9109 - val_loss: 0.3008 - learning_rate: 0.0010
# Epoch 6/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8689 - loss: 0.3782
# Epoch 6: val_categorical_accuracy improved from 0.91085 to 0.93217, saving model to Wild_CNN_best.keras
#
# Epoch 6: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - categorical_accuracy: 0.8792 - loss: 0.3529 - val_categorical_accuracy: 0.9322 - val_loss: 0.2350 - learning_rate: 0.0010
# Epoch 7/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.8959 - loss: 0.3186
# Epoch 7: val_categorical_accuracy did not improve from 0.93217
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.8950 - loss: 0.3187 - val_categorical_accuracy: 0.9037 - val_loss: 0.3230 - learning_rate: 0.0010
# Epoch 8/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9029 - loss: 0.2904
# Epoch 8: val_categorical_accuracy did not improve from 0.93217
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - categorical_accuracy: 0.9070 - loss: 0.2903 - val_categorical_accuracy: 0.9283 - val_loss: 0.2444 - learning_rate: 0.0010
# Epoch 9/200
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9197 - loss: 0.2480
# Epoch 9: val_categorical_accuracy did not improve from 0.93217
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9193 - loss: 0.2593 - val_categorical_accuracy: 0.9309 - val_loss: 0.2377 - learning_rate: 0.0010
# Epoch 10/200
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9171 - loss: 0.2522
# Epoch 10: val_categorical_accuracy improved from 0.93217 to 0.94509, saving model to Wild_CNN_best.keras
#
# Epoch 10: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - categorical_accuracy: 0.9212 - loss: 0.2399 - val_categorical_accuracy: 0.9451 - val_loss: 0.2026 - learning_rate: 0.0010
# Epoch 11/200
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9165 - loss: 0.2595
# Epoch 11: val_categorical_accuracy did not improve from 0.94509
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9186 - loss: 0.2489 - val_categorical_accuracy: 0.9354 - val_loss: 0.2213 - learning_rate: 0.0010
# Epoch 12/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9266 - loss: 0.2189
# Epoch 12: val_categorical_accuracy improved from 0.94509 to 0.94574, saving model to Wild_CNN_best.keras
#
# Epoch 12: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9217 - loss: 0.2357 - val_categorical_accuracy: 0.9457 - val_loss: 0.1832 - learning_rate: 0.0010
# Epoch 13/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9229 - loss: 0.2202
# Epoch 13: val_categorical_accuracy improved from 0.94574 to 0.95284, saving model to Wild_CNN_best.keras
#
# Epoch 13: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9231 - loss: 0.2280 - val_categorical_accuracy: 0.9528 - val_loss: 0.1895 - learning_rate: 0.0010
# Epoch 14/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - categorical_accuracy: 0.9248 - loss: 0.2172
# Epoch 14: val_categorical_accuracy did not improve from 0.95284
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - categorical_accuracy: 0.9318 - loss: 0.2021 - val_categorical_accuracy: 0.9399 - val_loss: 0.2166 - learning_rate: 0.0010
# Epoch 15/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9236 - loss: 0.2289
# Epoch 15: val_categorical_accuracy did not improve from 0.95284
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - categorical_accuracy: 0.9259 - loss: 0.2174 - val_categorical_accuracy: 0.9276 - val_loss: 0.2326 - learning_rate: 0.0010
# Epoch 16/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9334 - loss: 0.1999
# Epoch 16: val_categorical_accuracy did not improve from 0.95284
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9314 - loss: 0.2030 - val_categorical_accuracy: 0.9432 - val_loss: 0.2131 - learning_rate: 0.0010
# Epoch 17/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9379 - loss: 0.1856
# Epoch 17: val_categorical_accuracy did not improve from 0.95284
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9351 - loss: 0.1907 - val_categorical_accuracy: 0.9464 - val_loss: 0.1744 - learning_rate: 0.0010
# Epoch 18/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9400 - loss: 0.1770
# Epoch 18: val_categorical_accuracy did not improve from 0.95284
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9344 - loss: 0.1895 - val_categorical_accuracy: 0.9483 - val_loss: 0.1973 - learning_rate: 0.0010
# Epoch 19/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9428 - loss: 0.1858
# Epoch 19: val_categorical_accuracy did not improve from 0.95284
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9369 - loss: 0.1866 - val_categorical_accuracy: 0.9457 - val_loss: 0.1890 - learning_rate: 0.0010
# Epoch 20/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9406 - loss: 0.1661
# Epoch 20: val_categorical_accuracy improved from 0.95284 to 0.95801, saving model to Wild_CNN_best.keras
#
# Epoch 20: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - categorical_accuracy: 0.9402 - loss: 0.1735 - val_categorical_accuracy: 0.9580 - val_loss: 0.1633 - learning_rate: 0.0010
# Epoch 21/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9535 - loss: 0.1483
# Epoch 21: val_categorical_accuracy did not improve from 0.95801
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9459 - loss: 0.1698 - val_categorical_accuracy: 0.9541 - val_loss: 0.1666 - learning_rate: 0.0010
# Epoch 22/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9479 - loss: 0.1505
# Epoch 22: val_categorical_accuracy did not improve from 0.95801
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9465 - loss: 0.1552 - val_categorical_accuracy: 0.9354 - val_loss: 0.2486 - learning_rate: 0.0010
# Epoch 23/200
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9462 - loss: 0.1710
# Epoch 23: val_categorical_accuracy did not improve from 0.95801
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9449 - loss: 0.1679 - val_categorical_accuracy: 0.9490 - val_loss: 0.1800 - learning_rate: 0.0010
# Epoch 24/200
# 186/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9441 - loss: 0.1702
# Epoch 24: val_categorical_accuracy did not improve from 0.95801
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9432 - loss: 0.1682 - val_categorical_accuracy: 0.9541 - val_loss: 0.1642 - learning_rate: 0.0010
# Epoch 25/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9460 - loss: 0.1536
# Epoch 25: val_categorical_accuracy did not improve from 0.95801
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9465 - loss: 0.1618 - val_categorical_accuracy: 0.9412 - val_loss: 0.1847 - learning_rate: 0.0010
# Epoch 26/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9521 - loss: 0.1386
# Epoch 26: val_categorical_accuracy did not improve from 0.95801
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9530 - loss: 0.1387 - val_categorical_accuracy: 0.9548 - val_loss: 0.1578 - learning_rate: 0.0010
# Epoch 27/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9526 - loss: 0.1337
# Epoch 27: val_categorical_accuracy did not improve from 0.95801
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9490 - loss: 0.1456 - val_categorical_accuracy: 0.9554 - val_loss: 0.1508 - learning_rate: 0.0010
# Epoch 28/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9563 - loss: 0.1382
# Epoch 28: val_categorical_accuracy did not improve from 0.95801
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9564 - loss: 0.1354 - val_categorical_accuracy: 0.9457 - val_loss: 0.1876 - learning_rate: 0.0010
# Epoch 29/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9517 - loss: 0.1573
# Epoch 29: val_categorical_accuracy improved from 0.95801 to 0.95930, saving model to Wild_CNN_best.keras
#
# Epoch 29: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9548 - loss: 0.1444 - val_categorical_accuracy: 0.9593 - val_loss: 0.1495 - learning_rate: 0.0010
# Epoch 30/200
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9613 - loss: 0.1170
# Epoch 30: val_categorical_accuracy did not improve from 0.95930
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9585 - loss: 0.1261 - val_categorical_accuracy: 0.9548 - val_loss: 0.1702 - learning_rate: 0.0010
# Epoch 31/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9610 - loss: 0.1318
# Epoch 31: val_categorical_accuracy did not improve from 0.95930
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9603 - loss: 0.1269 - val_categorical_accuracy: 0.9554 - val_loss: 0.1671 - learning_rate: 0.0010
# Epoch 32/200
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9565 - loss: 0.1262
# Epoch 32: val_categorical_accuracy did not improve from 0.95930
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9580 - loss: 0.1309 - val_categorical_accuracy: 0.9567 - val_loss: 0.2011 - learning_rate: 0.0010
# Epoch 33/200
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9533 - loss: 0.1431
# Epoch 33: val_categorical_accuracy did not improve from 0.95930
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9495 - loss: 0.1474 - val_categorical_accuracy: 0.9548 - val_loss: 0.1682 - learning_rate: 0.0010
# Epoch 34/200
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9590 - loss: 0.1180
# Epoch 34: val_categorical_accuracy did not improve from 0.95930
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9570 - loss: 0.1256 - val_categorical_accuracy: 0.9554 - val_loss: 0.1840 - learning_rate: 0.0010
# Epoch 35/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9606 - loss: 0.1198
# Epoch 35: val_categorical_accuracy did not improve from 0.95930
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9598 - loss: 0.1179 - val_categorical_accuracy: 0.9483 - val_loss: 0.1883 - learning_rate: 0.0010
# Epoch 36/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9574 - loss: 0.1308
# Epoch 36: val_categorical_accuracy did not improve from 0.95930
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9545 - loss: 0.1369 - val_categorical_accuracy: 0.9522 - val_loss: 0.2007 - learning_rate: 0.0010
# Epoch 37/200
# 186/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9564 - loss: 0.1231
# Epoch 37: val_categorical_accuracy improved from 0.95930 to 0.96318, saving model to Wild_CNN_best.keras
#
# Epoch 37: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9588 - loss: 0.1228 - val_categorical_accuracy: 0.9632 - val_loss: 0.1424 - learning_rate: 0.0010
# Epoch 38/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9558 - loss: 0.1252
# Epoch 38: val_categorical_accuracy did not improve from 0.96318
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9596 - loss: 0.1204 - val_categorical_accuracy: 0.9612 - val_loss: 0.1275 - learning_rate: 0.0010
# Epoch 39/200
# 187/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9626 - loss: 0.1128
# Epoch 39: val_categorical_accuracy did not improve from 0.96318
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9609 - loss: 0.1164 - val_categorical_accuracy: 0.9619 - val_loss: 0.1336 - learning_rate: 0.0010
# Epoch 40/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9684 - loss: 0.0963
# Epoch 40: val_categorical_accuracy improved from 0.96318 to 0.96382, saving model to Wild_CNN_best.keras
#
# Epoch 40: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - categorical_accuracy: 0.9648 - loss: 0.1037 - val_categorical_accuracy: 0.9638 - val_loss: 0.1332 - learning_rate: 0.0010
# Epoch 41/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9662 - loss: 0.0940
# Epoch 41: val_categorical_accuracy did not improve from 0.96382
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9637 - loss: 0.1047 - val_categorical_accuracy: 0.9580 - val_loss: 0.1573 - learning_rate: 0.0010
# Epoch 42/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9621 - loss: 0.1112
# Epoch 42: val_categorical_accuracy did not improve from 0.96382
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9666 - loss: 0.1037 - val_categorical_accuracy: 0.9587 - val_loss: 0.1445 - learning_rate: 0.0010
# Epoch 43/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9667 - loss: 0.0970
# Epoch 43: val_categorical_accuracy did not improve from 0.96382
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9669 - loss: 0.0970 - val_categorical_accuracy: 0.9632 - val_loss: 0.1465 - learning_rate: 0.0010
# Epoch 44/200
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9672 - loss: 0.1062
# Epoch 44: val_categorical_accuracy did not improve from 0.96382
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9656 - loss: 0.1069 - val_categorical_accuracy: 0.9625 - val_loss: 0.1337 - learning_rate: 0.0010
# Epoch 45/200
# 187/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9651 - loss: 0.0969
# Epoch 45: val_categorical_accuracy improved from 0.96382 to 0.96705, saving model to Wild_CNN_best.keras
#
# Epoch 45: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9650 - loss: 0.0984 - val_categorical_accuracy: 0.9671 - val_loss: 0.1346 - learning_rate: 0.0010
# Epoch 46/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9655 - loss: 0.1034
# Epoch 46: val_categorical_accuracy did not improve from 0.96705
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9671 - loss: 0.0999 - val_categorical_accuracy: 0.9606 - val_loss: 0.1420 - learning_rate: 0.0010
# Epoch 47/200
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9644 - loss: 0.1112
# Epoch 47: val_categorical_accuracy did not improve from 0.96705
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9685 - loss: 0.0926 - val_categorical_accuracy: 0.9432 - val_loss: 0.2091 - learning_rate: 0.0010
# Epoch 48/200
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9658 - loss: 0.0994
# Epoch 48: val_categorical_accuracy did not improve from 0.96705
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - categorical_accuracy: 0.9658 - loss: 0.1016 - val_categorical_accuracy: 0.9612 - val_loss: 0.1475 - learning_rate: 0.0010
# Epoch 49/200
# 186/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9662 - loss: 0.0896
# Epoch 49: val_categorical_accuracy improved from 0.96705 to 0.97351, saving model to Wild_CNN_best.keras
#
# Epoch 49: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9716 - loss: 0.0765 - val_categorical_accuracy: 0.9735 - val_loss: 0.1179 - learning_rate: 5.0000e-04
# Epoch 50/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9789 - loss: 0.0660
# Epoch 50: val_categorical_accuracy did not improve from 0.97351
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9797 - loss: 0.0624 - val_categorical_accuracy: 0.9703 - val_loss: 0.1040 - learning_rate: 5.0000e-04
# Epoch 51/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9808 - loss: 0.0582
# Epoch 51: val_categorical_accuracy did not improve from 0.97351
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9801 - loss: 0.0605 - val_categorical_accuracy: 0.9729 - val_loss: 0.1009 - learning_rate: 5.0000e-04
# Epoch 52/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9797 - loss: 0.0588
# Epoch 52: val_categorical_accuracy did not improve from 0.97351
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9803 - loss: 0.0549 - val_categorical_accuracy: 0.9671 - val_loss: 0.1118 - learning_rate: 5.0000e-04
# Epoch 53/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9821 - loss: 0.0678
# Epoch 53: val_categorical_accuracy did not improve from 0.97351
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9821 - loss: 0.0612 - val_categorical_accuracy: 0.9690 - val_loss: 0.1193 - learning_rate: 5.0000e-04
# Epoch 54/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9794 - loss: 0.0582
# Epoch 54: val_categorical_accuracy improved from 0.97351 to 0.97545, saving model to Wild_CNN_best.keras
#
# Epoch 54: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9805 - loss: 0.0579 - val_categorical_accuracy: 0.9755 - val_loss: 0.1028 - learning_rate: 5.0000e-04
# Epoch 55/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9863 - loss: 0.0464
# Epoch 55: val_categorical_accuracy did not improve from 0.97545
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9837 - loss: 0.0528 - val_categorical_accuracy: 0.9677 - val_loss: 0.1308 - learning_rate: 5.0000e-04
# Epoch 56/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9810 - loss: 0.0603
# Epoch 56: val_categorical_accuracy did not improve from 0.97545
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9795 - loss: 0.0594 - val_categorical_accuracy: 0.9735 - val_loss: 0.1039 - learning_rate: 5.0000e-04
# Epoch 57/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9774 - loss: 0.0602
# Epoch 57: val_categorical_accuracy did not improve from 0.97545
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9780 - loss: 0.0609 - val_categorical_accuracy: 0.9709 - val_loss: 0.1108 - learning_rate: 5.0000e-04
# Epoch 58/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9789 - loss: 0.0608
# Epoch 58: val_categorical_accuracy improved from 0.97545 to 0.97739, saving model to Wild_CNN_best.keras
#
# Epoch 58: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9829 - loss: 0.0518 - val_categorical_accuracy: 0.9774 - val_loss: 0.0993 - learning_rate: 5.0000e-04
# Epoch 59/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9856 - loss: 0.0430
# Epoch 59: val_categorical_accuracy did not improve from 0.97739
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9824 - loss: 0.0534 - val_categorical_accuracy: 0.9722 - val_loss: 0.1105 - learning_rate: 5.0000e-04
# Epoch 60/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9787 - loss: 0.0642
# Epoch 60: val_categorical_accuracy improved from 0.97739 to 0.97804, saving model to Wild_CNN_best.keras
#
# Epoch 60: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9813 - loss: 0.0542 - val_categorical_accuracy: 0.9780 - val_loss: 0.0952 - learning_rate: 5.0000e-04
# Epoch 61/200
# 186/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9826 - loss: 0.0483
# Epoch 61: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9826 - loss: 0.0493 - val_categorical_accuracy: 0.9729 - val_loss: 0.0962 - learning_rate: 5.0000e-04
# Epoch 62/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9855 - loss: 0.0424
# Epoch 62: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9861 - loss: 0.0433 - val_categorical_accuracy: 0.9735 - val_loss: 0.0976 - learning_rate: 5.0000e-04
# Epoch 63/200
# 187/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9808 - loss: 0.0499
# Epoch 63: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9806 - loss: 0.0516 - val_categorical_accuracy: 0.9677 - val_loss: 0.1108 - learning_rate: 5.0000e-04
# Epoch 64/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9789 - loss: 0.0565
# Epoch 64: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9787 - loss: 0.0564 - val_categorical_accuracy: 0.9709 - val_loss: 0.1169 - learning_rate: 5.0000e-04
# Epoch 65/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9866 - loss: 0.0464
# Epoch 65: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9858 - loss: 0.0465 - val_categorical_accuracy: 0.9780 - val_loss: 0.0960 - learning_rate: 5.0000e-04
# Epoch 66/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9846 - loss: 0.0436
# Epoch 66: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - categorical_accuracy: 0.9837 - loss: 0.0493 - val_categorical_accuracy: 0.9716 - val_loss: 0.1112 - learning_rate: 5.0000e-04
# Epoch 67/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9794 - loss: 0.0546
# Epoch 67: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9826 - loss: 0.0481 - val_categorical_accuracy: 0.9729 - val_loss: 0.1052 - learning_rate: 5.0000e-04
# Epoch 68/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9860 - loss: 0.0345
# Epoch 68: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9853 - loss: 0.0412 - val_categorical_accuracy: 0.9735 - val_loss: 0.0983 - learning_rate: 5.0000e-04
# Epoch 69/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9837 - loss: 0.0470
# Epoch 69: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9832 - loss: 0.0486 - val_categorical_accuracy: 0.9722 - val_loss: 0.0987 - learning_rate: 5.0000e-04
# Epoch 70/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9884 - loss: 0.0376
# Epoch 70: val_categorical_accuracy did not improve from 0.97804
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9839 - loss: 0.0435 - val_categorical_accuracy: 0.9780 - val_loss: 0.1010 - learning_rate: 5.0000e-04
# Epoch 71/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9880 - loss: 0.0306
# Epoch 71: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9877 - loss: 0.0318 - val_categorical_accuracy: 0.9767 - val_loss: 0.1044 - learning_rate: 2.5000e-04
# Epoch 72/200
# 187/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9867 - loss: 0.0374
# Epoch 72: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9885 - loss: 0.0333 - val_categorical_accuracy: 0.9780 - val_loss: 0.0937 - learning_rate: 2.5000e-04
# Epoch 73/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9877 - loss: 0.0377
# Epoch 73: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9876 - loss: 0.0361 - val_categorical_accuracy: 0.9774 - val_loss: 0.0979 - learning_rate: 2.5000e-04
# Epoch 74/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9910 - loss: 0.0277
# Epoch 74: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9908 - loss: 0.0293 - val_categorical_accuracy: 0.9780 - val_loss: 0.0893 - learning_rate: 2.5000e-04
# Epoch 75/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9891 - loss: 0.0308
# Epoch 75: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9893 - loss: 0.0308 - val_categorical_accuracy: 0.9742 - val_loss: 0.1098 - learning_rate: 2.5000e-04
# Epoch 76/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9885 - loss: 0.0352
# Epoch 76: val_categorical_accuracy did not improve from 0.97804
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9884 - loss: 0.0334 - val_categorical_accuracy: 0.9755 - val_loss: 0.1030 - learning_rate: 2.5000e-04
# Epoch 77/200
# 186/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9881 - loss: 0.0331
# Epoch 77: val_categorical_accuracy improved from 0.97804 to 0.97868, saving model to Wild_CNN_best.keras
#
# Epoch 77: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9892 - loss: 0.0317 - val_categorical_accuracy: 0.9787 - val_loss: 0.0899 - learning_rate: 2.5000e-04
# Epoch 78/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9913 - loss: 0.0257
# Epoch 78: val_categorical_accuracy did not improve from 0.97868
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9911 - loss: 0.0257 - val_categorical_accuracy: 0.9774 - val_loss: 0.0899 - learning_rate: 2.5000e-04
# Epoch 79/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9882 - loss: 0.0316
# Epoch 79: val_categorical_accuracy did not improve from 0.97868
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9887 - loss: 0.0309 - val_categorical_accuracy: 0.9729 - val_loss: 0.1008 - learning_rate: 2.5000e-04
# Epoch 80/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9862 - loss: 0.0301
# Epoch 80: val_categorical_accuracy did not improve from 0.97868
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9885 - loss: 0.0302 - val_categorical_accuracy: 0.9780 - val_loss: 0.0971 - learning_rate: 2.5000e-04
# Epoch 81/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9911 - loss: 0.0250
# Epoch 81: val_categorical_accuracy did not improve from 0.97868
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9898 - loss: 0.0289 - val_categorical_accuracy: 0.9755 - val_loss: 0.0972 - learning_rate: 2.5000e-04
# Epoch 82/200
# 186/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9909 - loss: 0.0298
# Epoch 82: val_categorical_accuracy did not improve from 0.97868
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9913 - loss: 0.0273 - val_categorical_accuracy: 0.9774 - val_loss: 0.0961 - learning_rate: 2.5000e-04
# Epoch 83/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9874 - loss: 0.0407
# Epoch 83: val_categorical_accuracy improved from 0.97868 to 0.97933, saving model to Wild_CNN_best.keras
#
# Epoch 83: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - categorical_accuracy: 0.9895 - loss: 0.0337 - val_categorical_accuracy: 0.9793 - val_loss: 0.1001 - learning_rate: 2.5000e-04
# Epoch 84/200
# 187/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9933 - loss: 0.0221
# Epoch 84: val_categorical_accuracy did not improve from 0.97933
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9924 - loss: 0.0262 - val_categorical_accuracy: 0.9755 - val_loss: 0.1092 - learning_rate: 2.5000e-04
# Epoch 85/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9901 - loss: 0.0264
# Epoch 85: val_categorical_accuracy did not improve from 0.97933
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9901 - loss: 0.0277 - val_categorical_accuracy: 0.9780 - val_loss: 0.0874 - learning_rate: 1.2500e-04
# Epoch 86/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9929 - loss: 0.0234
# Epoch 86: val_categorical_accuracy did not improve from 0.97933
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9924 - loss: 0.0228 - val_categorical_accuracy: 0.9787 - val_loss: 0.0955 - learning_rate: 1.2500e-04
# Epoch 87/200
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - categorical_accuracy: 0.9924 - loss: 0.0239
# Epoch 87: val_categorical_accuracy did not improve from 0.97933
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - categorical_accuracy: 0.9927 - loss: 0.0226 - val_categorical_accuracy: 0.9780 - val_loss: 0.0908 - learning_rate: 1.2500e-04
# Epoch 88/200
# 187/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9913 - loss: 0.0268
# Epoch 88: val_categorical_accuracy improved from 0.97933 to 0.98062, saving model to Wild_CNN_best.keras
#
# Epoch 88: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9931 - loss: 0.0216 - val_categorical_accuracy: 0.9806 - val_loss: 0.0938 - learning_rate: 1.2500e-04
# Epoch 89/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9924 - loss: 0.0214
# Epoch 89: val_categorical_accuracy did not improve from 0.98062
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9906 - loss: 0.0270 - val_categorical_accuracy: 0.9800 - val_loss: 0.0925 - learning_rate: 1.2500e-04
# Epoch 90/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9919 - loss: 0.0202
# Epoch 90: val_categorical_accuracy did not improve from 0.98062
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9929 - loss: 0.0187 - val_categorical_accuracy: 0.9800 - val_loss: 0.0913 - learning_rate: 1.2500e-04
# Epoch 91/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9931 - loss: 0.0209
# Epoch 91: val_categorical_accuracy improved from 0.98062 to 0.98256, saving model to Wild_CNN_best.keras
#
# Epoch 91: finished saving model to Wild_CNN_best.keras
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9921 - loss: 0.0207 - val_categorical_accuracy: 0.9826 - val_loss: 0.0858 - learning_rate: 1.2500e-04
# Epoch 92/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9924 - loss: 0.0247
# Epoch 92: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9913 - loss: 0.0264 - val_categorical_accuracy: 0.9806 - val_loss: 0.0902 - learning_rate: 1.2500e-04
# Epoch 93/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9908 - loss: 0.0234
# Epoch 93: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9931 - loss: 0.0192 - val_categorical_accuracy: 0.9780 - val_loss: 0.0860 - learning_rate: 1.2500e-04
# Epoch 94/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9917 - loss: 0.0241
# Epoch 94: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9934 - loss: 0.0208 - val_categorical_accuracy: 0.9813 - val_loss: 0.0951 - learning_rate: 1.2500e-04
# Epoch 95/200
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9951 - loss: 0.0163
# Epoch 95: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9945 - loss: 0.0187 - val_categorical_accuracy: 0.9826 - val_loss: 0.0923 - learning_rate: 1.2500e-04
# Epoch 96/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9947 - loss: 0.0168
# Epoch 96: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9935 - loss: 0.0208 - val_categorical_accuracy: 0.9813 - val_loss: 0.0903 - learning_rate: 1.2500e-04
# Epoch 97/200
# 187/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9955 - loss: 0.0164
# Epoch 97: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9945 - loss: 0.0178 - val_categorical_accuracy: 0.9793 - val_loss: 0.0909 - learning_rate: 1.2500e-04
# Epoch 98/200
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9950 - loss: 0.0181
# Epoch 98: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9934 - loss: 0.0207 - val_categorical_accuracy: 0.9787 - val_loss: 0.0882 - learning_rate: 1.2500e-04
# Epoch 99/200
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9951 - loss: 0.0197
# Epoch 99: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9945 - loss: 0.0188 - val_categorical_accuracy: 0.9819 - val_loss: 0.0903 - learning_rate: 1.2500e-04
# Epoch 100/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9915 - loss: 0.0237
# Epoch 100: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9924 - loss: 0.0227 - val_categorical_accuracy: 0.9774 - val_loss: 0.0898 - learning_rate: 1.2500e-04
# Epoch 101/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9943 - loss: 0.0164
# Epoch 101: val_categorical_accuracy did not improve from 0.98256
#
# Epoch 101: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9942 - loss: 0.0171 - val_categorical_accuracy: 0.9813 - val_loss: 0.0885 - learning_rate: 1.2500e-04
# Epoch 102/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9952 - loss: 0.0148
# Epoch 102: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9945 - loss: 0.0179 - val_categorical_accuracy: 0.9800 - val_loss: 0.0862 - learning_rate: 6.2500e-05
# Epoch 103/200
# 186/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9940 - loss: 0.0191
# Epoch 103: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9934 - loss: 0.0197 - val_categorical_accuracy: 0.9806 - val_loss: 0.0861 - learning_rate: 6.2500e-05
# Epoch 104/200
# 187/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9959 - loss: 0.0154
# Epoch 104: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9956 - loss: 0.0157 - val_categorical_accuracy: 0.9787 - val_loss: 0.0944 - learning_rate: 6.2500e-05
# Epoch 105/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9938 - loss: 0.0158
# Epoch 105: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9942 - loss: 0.0158 - val_categorical_accuracy: 0.9806 - val_loss: 0.0897 - learning_rate: 6.2500e-05
# Epoch 106/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9923 - loss: 0.0222
# Epoch 106: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9918 - loss: 0.0240 - val_categorical_accuracy: 0.9826 - val_loss: 0.0856 - learning_rate: 6.2500e-05
# Epoch 107/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9939 - loss: 0.0160
# Epoch 107: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9945 - loss: 0.0163 - val_categorical_accuracy: 0.9826 - val_loss: 0.0867 - learning_rate: 6.2500e-05
# Epoch 108/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9946 - loss: 0.0173
# Epoch 108: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9937 - loss: 0.0187 - val_categorical_accuracy: 0.9826 - val_loss: 0.0920 - learning_rate: 6.2500e-05
# Epoch 109/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9951 - loss: 0.0165
# Epoch 109: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9947 - loss: 0.0175 - val_categorical_accuracy: 0.9806 - val_loss: 0.0895 - learning_rate: 6.2500e-05
# Epoch 110/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9963 - loss: 0.0150
# Epoch 110: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9955 - loss: 0.0172 - val_categorical_accuracy: 0.9813 - val_loss: 0.0884 - learning_rate: 6.2500e-05
# Epoch 111/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9944 - loss: 0.0174
# Epoch 111: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9935 - loss: 0.0187 - val_categorical_accuracy: 0.9813 - val_loss: 0.0874 - learning_rate: 6.2500e-05
# Epoch 112/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9911 - loss: 0.0233
# Epoch 112: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9931 - loss: 0.0194 - val_categorical_accuracy: 0.9813 - val_loss: 0.0878 - learning_rate: 6.2500e-05
# Epoch 113/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9925 - loss: 0.0188
# Epoch 113: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9937 - loss: 0.0182 - val_categorical_accuracy: 0.9813 - val_loss: 0.0891 - learning_rate: 6.2500e-05
# Epoch 114/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - categorical_accuracy: 0.9937 - loss: 0.0193
# Epoch 114: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - categorical_accuracy: 0.9940 - loss: 0.0181 - val_categorical_accuracy: 0.9813 - val_loss: 0.0838 - learning_rate: 6.2500e-05
# Epoch 115/200
# 188/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9954 - loss: 0.0141
# Epoch 115: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9943 - loss: 0.0165 - val_categorical_accuracy: 0.9806 - val_loss: 0.0828 - learning_rate: 6.2500e-05
# Epoch 116/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9952 - loss: 0.0152
# Epoch 116: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9955 - loss: 0.0150 - val_categorical_accuracy: 0.9813 - val_loss: 0.0853 - learning_rate: 6.2500e-05
# Epoch 117/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9954 - loss: 0.0138
# Epoch 117: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9948 - loss: 0.0155 - val_categorical_accuracy: 0.9813 - val_loss: 0.0835 - learning_rate: 6.2500e-05
# Epoch 118/200
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9908 - loss: 0.0325
# Epoch 118: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9939 - loss: 0.0213 - val_categorical_accuracy: 0.9806 - val_loss: 0.0845 - learning_rate: 6.2500e-05
# Epoch 119/200
# 189/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9959 - loss: 0.0154
# Epoch 119: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9958 - loss: 0.0136 - val_categorical_accuracy: 0.9806 - val_loss: 0.0876 - learning_rate: 6.2500e-05
# Epoch 120/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - categorical_accuracy: 0.9949 - loss: 0.0134
# Epoch 120: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - categorical_accuracy: 0.9947 - loss: 0.0142 - val_categorical_accuracy: 0.9813 - val_loss: 0.0872 - learning_rate: 6.2500e-05
# Epoch 121/200
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9969 - loss: 0.0121
# Epoch 121: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9958 - loss: 0.0141 - val_categorical_accuracy: 0.9806 - val_loss: 0.0860 - learning_rate: 6.2500e-05
# Epoch 122/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9951 - loss: 0.0151
# Epoch 122: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9947 - loss: 0.0141 - val_categorical_accuracy: 0.9819 - val_loss: 0.0819 - learning_rate: 6.2500e-05
# Epoch 123/200
# 191/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9943 - loss: 0.0203
# Epoch 123: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9948 - loss: 0.0171 - val_categorical_accuracy: 0.9819 - val_loss: 0.0849 - learning_rate: 6.2500e-05
# Epoch 124/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9957 - loss: 0.0154
# Epoch 124: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9952 - loss: 0.0163 - val_categorical_accuracy: 0.9813 - val_loss: 0.0873 - learning_rate: 6.2500e-05
# Epoch 125/200
# 193/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9954 - loss: 0.0176
# Epoch 125: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - categorical_accuracy: 0.9947 - loss: 0.0161 - val_categorical_accuracy: 0.9819 - val_loss: 0.0809 - learning_rate: 6.2500e-05
# Epoch 126/200
# 192/194 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.9959 - loss: 0.0121
# Epoch 126: val_categorical_accuracy did not improve from 0.98256
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - categorical_accuracy: 0.9952 - loss: 0.0147 - val_categorical_accuracy: 0.9819 - val_loss: 0.0840 - learning_rate: 6.2500e-05
# Epoch 126: early stopping
# Restoring model weights from the end of the best epoch: 91.

# %% [markdown]
# # Model Evaluation

# %%
# best 기록 확인
model = tf.keras.models.load_model("Wild_CNN_best.keras")

train_loss, train_acc = model.evaluate(X_train, y_train_onehot, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test_onehot, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# Training accuracy: 99.50%
# Training loss: 0.0222
# Test accuracy: 97.42%
# Test loss: 0.0925

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# f1-score 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9790    0.9655    0.9722       290
#            1     0.9841    0.9657    0.9748       321
#            2     0.9774    0.9943    0.9858       348
#            3     0.9685    0.9624    0.9654       319
#            4     0.9666    0.9731    0.9698       297
#            5     0.9699    0.9806    0.9752       361
#
#     accuracy                         0.9742      1936
#    macro avg     0.9742    0.9736    0.9739      1936
# weighted avg     0.9742    0.9742    0.9742      1936

# %%
# loss / accuracy 그래프
train_loss = history.history['loss']
train_accuracy = history.history['categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.ylim([0.0, 1.0])
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# 혼동행렬(히트맵)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=LABELS,
            yticklabels=LABELS)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
