# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, BatchNormalization, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

LABELS = [
    "WALKING",
    "WALKING_UPSTAIRS",
    "WALKING_DOWNSTAIRS",
    "SITTING",
    "STANDING",
    "LAYING"
]

# %%
TRAIN = "train/"
TEST = "test/"

DATASET_PATH = "/content/drive/MyDrive/AI_assignment/UCI_HAR_Dataset/"

# %%
# Load "X"
def load_X(X_signals_paths):
    X_signals = []

    for signal_type_path in X_signals_paths:
        series_list = []  # 한 센서축 데이터 전체 저장

        with open(signal_type_path, 'r') as file:
            for row in file:
                row_clean = row.replace('  ', ' ')              # 공백 2개를 1개로
                row_clean = row_clean.strip()                   # 양쪽 공백 제거
                serie = row_clean.split(' ')                    # 공백 기준 split
                serie_array = np.array(serie, dtype=np.float32) # float32 numpy 배열로 변환
                series_list.append(serie_array)                 # 시퀀스 추가

        # 하나의 센서축 데이터 추가 (feature)
        X_signals.append(series_list)

    # shape: (특성 수, 샘플 수, 타임스텝 수)
    X_signals = np.array(X_signals)
    # shape 변환 → (샘플 수, 타임스텝 수, 특성 수)
    return np.transpose(X_signals, (1, 2, 0))


X_train_signals_paths = [
    DATASET_PATH + TRAIN + "Inertial_Signals/" + signal + "train.txt"
    for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    DATASET_PATH + TEST + "Inertial_Signals/" + signal + "test.txt"
    for signal in INPUT_SIGNAL_TYPES
]

X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("첫 번째 샘플 데이터:\n", X_train[0])
# Out:
# X_train shape: (7352, 128, 9)
# X_test shape: (2947, 128, 9)
# 첫 번째 샘플 데이터:
#  [[ 1.808515e-04  1.076681e-02  5.556068e-02 ...  1.012817e+00
#   -1.232167e-01  1.029341e-01]
#  [ 1.013856e-02  6.579480e-03  5.512483e-02 ...  1.022833e+00
#   -1.268756e-01  1.056872e-01]
#  [ 9.275574e-03  8.928878e-03  4.840473e-02 ...  1.022028e+00
#   -1.240037e-01  1.021025e-01]
#  ...
#  [-1.147484e-03  1.714439e-04  2.647864e-03 ...  1.018445e+00
#   -1.240696e-01  1.003852e-01]
#  [-2.222655e-04  1.574181e-03  2.381057e-03 ...  1.019372e+00
#   -1.227451e-01  9.987355e-02]
#  [ 1.575500e-03  3.070189e-03 -2.269757e-03 ...  1.021171e+00
#   -1.213260e-01  9.498741e-02]]

# %%
# Load "y"

def load_y(y_path):
    with open(y_path, 'r') as file:
        labels = [int(line.strip()) for line in file]
    # 라벨을 0부터 시작하도록 -1 (원래 라벨이 1부터 시작)
    return np.array(labels, dtype=np.int32) - 1


y_train_path = DATASET_PATH + TRAIN + "y_train.txt"
y_test_path = DATASET_PATH + TEST + "y_test.txt"

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
print(y_train[:5])
# Out:
# y_train shape: (7352,)
# y_test shape: (2947,)
# [4 4 4 4 4]

# %% [markdown]
# # RNN 모델 설계
# - Layer : rnn 층 3개 + Dense 층 2개

# %%
input_shape = (X_train.shape[1], X_train.shape[2])
num_classes = 6

K.clear_session()

custom_optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005, clipvalue=1.0)

model = Sequential([
            Input(shape=input_shape),

            # 첫번째 rnn층
            SimpleRNN(128, return_sequences=True, dropout=0.2),
            BatchNormalization(),

            # 두번째 rnn층
            SimpleRNN(128, kernel_regularizer=regularizers.l2(0.001), return_sequences=True, dropout=0.2),
            BatchNormalization(),

            # 세번째 rnn층
            SimpleRNN(64, dropout=0.2),
            BatchNormalization(),

            # dense층 2개
            Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
            BatchNormalization(),
            Dropout(0.5),
            Dense(num_classes, activation='softmax')
        ])

model.compile(
            optimizer=custom_optimizer,
            loss='sparse_categorical_crossentropy',
            metrics=['sparse_categorical_accuracy']
        )

print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 128, 128)       │        17,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 128, 128)       │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 64)             │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,798 (288.27 KB)
#  Trainable params: 72,902 (284.77 KB)
#  Non-trainable params: 896 (3.50 KB)
# None

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# # callbacks 설정

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_HAR_RNN_best.keras",
                save_best_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=30,
                verbose=1,
                mode='max',
                restore_best_weights=True
            ),
            ReduceLROnPlateau(
                monitor='val_loss',    # val_loss 값을 지켜보다가
                factor=0.2,            # 학습에 발전이 없으면 LR에 0.2를 곱함 (기존의 1/5 수준으로 감소)
                patience=10,            # 5번 epochs 동안 성적이 안 오르면 실행
                min_lr=0.00001,        # 최소 LR 지정
                verbose=1              # LR이 바뀔 때 화면에 메시지 출력
            )
        ]

# %% [markdown]
# # 모델 학습

# %%
history = model.fit(
            X_train, y_train,
            epochs=150,
            batch_size=64,
            validation_split=0.2,
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 2.2025 - sparse_categorical_accuracy: 0.3892
# Epoch 1: val_sparse_categorical_accuracy improved from None to 0.53773, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 1: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 25s 200ms/step - loss: 1.9084 - sparse_categorical_accuracy: 0.4543 - val_loss: 1.6726 - val_sparse_categorical_accuracy: 0.5377 - learning_rate: 5.0000e-04
# Epoch 2/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 1.4608 - sparse_categorical_accuracy: 0.5273
# Epoch 2: val_sparse_categorical_accuracy did not improve from 0.53773
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - loss: 1.4028 - sparse_categorical_accuracy: 0.5479 - val_loss: 1.7214 - val_sparse_categorical_accuracy: 0.4521 - learning_rate: 5.0000e-04
# Epoch 3/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 1.2947 - sparse_categorical_accuracy: 0.5708
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.53773
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 208ms/step - loss: 1.2576 - sparse_categorical_accuracy: 0.5775 - val_loss: 1.7640 - val_sparse_categorical_accuracy: 0.3222 - learning_rate: 5.0000e-04
# Epoch 4/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 1.1571 - sparse_categorical_accuracy: 0.5916
# Epoch 4: val_sparse_categorical_accuracy improved from 0.53773 to 0.65466, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 4: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 197ms/step - loss: 1.1566 - sparse_categorical_accuracy: 0.5909 - val_loss: 0.9777 - val_sparse_categorical_accuracy: 0.6547 - learning_rate: 5.0000e-04
# Epoch 5/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 1.0942 - sparse_categorical_accuracy: 0.6172
# Epoch 5: val_sparse_categorical_accuracy improved from 0.65466 to 0.68253, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 5: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 191ms/step - loss: 1.0928 - sparse_categorical_accuracy: 0.6149 - val_loss: 1.0435 - val_sparse_categorical_accuracy: 0.6825 - learning_rate: 5.0000e-04
# Epoch 6/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 1.0614 - sparse_categorical_accuracy: 0.6189
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.68253
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s 204ms/step - loss: 1.0549 - sparse_categorical_accuracy: 0.6240 - val_loss: 1.0495 - val_sparse_categorical_accuracy: 0.6302 - learning_rate: 5.0000e-04
# Epoch 7/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 1.0056 - sparse_categorical_accuracy: 0.6432
# Epoch 7: val_sparse_categorical_accuracy improved from 0.68253 to 0.77022, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 7: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 189ms/step - loss: 1.0084 - sparse_categorical_accuracy: 0.6295 - val_loss: 0.9744 - val_sparse_categorical_accuracy: 0.7702 - learning_rate: 5.0000e-04
# Epoch 8/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.9838 - sparse_categorical_accuracy: 0.6487
# Epoch 8: val_sparse_categorical_accuracy improved from 0.77022 to 0.78858, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 8: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - loss: 0.9707 - sparse_categorical_accuracy: 0.6547 - val_loss: 0.7998 - val_sparse_categorical_accuracy: 0.7886 - learning_rate: 5.0000e-04
# Epoch 9/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.9369 - sparse_categorical_accuracy: 0.6675
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.78858
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 199ms/step - loss: 0.9419 - sparse_categorical_accuracy: 0.6679 - val_loss: 0.8627 - val_sparse_categorical_accuracy: 0.7315 - learning_rate: 5.0000e-04
# Epoch 10/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.8919 - sparse_categorical_accuracy: 0.7001
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.78858
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 192ms/step - loss: 0.9123 - sparse_categorical_accuracy: 0.6871 - val_loss: 0.8591 - val_sparse_categorical_accuracy: 0.7437 - learning_rate: 5.0000e-04
# Epoch 11/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.8590 - sparse_categorical_accuracy: 0.7103
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.78858
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 189ms/step - loss: 0.8615 - sparse_categorical_accuracy: 0.7172 - val_loss: 0.7511 - val_sparse_categorical_accuracy: 0.7695 - learning_rate: 5.0000e-04
# Epoch 12/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.8542 - sparse_categorical_accuracy: 0.7127
# Epoch 12: val_sparse_categorical_accuracy improved from 0.78858 to 0.82869, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 12: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 196ms/step - loss: 0.8473 - sparse_categorical_accuracy: 0.7188 - val_loss: 0.6713 - val_sparse_categorical_accuracy: 0.8287 - learning_rate: 5.0000e-04
# Epoch 13/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.8925 - sparse_categorical_accuracy: 0.7084
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.82869
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 192ms/step - loss: 0.9017 - sparse_categorical_accuracy: 0.7029 - val_loss: 1.0126 - val_sparse_categorical_accuracy: 0.6723 - learning_rate: 5.0000e-04
# Epoch 14/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.7905 - sparse_categorical_accuracy: 0.7420
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.82869
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 189ms/step - loss: 0.7859 - sparse_categorical_accuracy: 0.7412 - val_loss: 0.8189 - val_sparse_categorical_accuracy: 0.7539 - learning_rate: 5.0000e-04
# Epoch 15/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.7388 - sparse_categorical_accuracy: 0.7599
# Epoch 15: val_sparse_categorical_accuracy improved from 0.82869 to 0.83413, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 15: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s 203ms/step - loss: 0.7414 - sparse_categorical_accuracy: 0.7619 - val_loss: 0.7252 - val_sparse_categorical_accuracy: 0.8341 - learning_rate: 5.0000e-04
# Epoch 16/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.7968 - sparse_categorical_accuracy: 0.7310
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.83413
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 197ms/step - loss: 0.7867 - sparse_categorical_accuracy: 0.7363 - val_loss: 0.7318 - val_sparse_categorical_accuracy: 0.7485 - learning_rate: 5.0000e-04
# Epoch 17/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.7325 - sparse_categorical_accuracy: 0.7604
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.83413
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 190ms/step - loss: 0.7470 - sparse_categorical_accuracy: 0.7582 - val_loss: 2.4384 - val_sparse_categorical_accuracy: 0.2896 - learning_rate: 5.0000e-04
# Epoch 18/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.9453 - sparse_categorical_accuracy: 0.6800
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.83413
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 192ms/step - loss: 0.8892 - sparse_categorical_accuracy: 0.6905 - val_loss: 0.8231 - val_sparse_categorical_accuracy: 0.7573 - learning_rate: 5.0000e-04
# Epoch 19/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.7921 - sparse_categorical_accuracy: 0.7268
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.83413
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 189ms/step - loss: 0.7971 - sparse_categorical_accuracy: 0.7283 - val_loss: 0.7250 - val_sparse_categorical_accuracy: 0.8029 - learning_rate: 5.0000e-04
# Epoch 20/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.7581 - sparse_categorical_accuracy: 0.7480
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.83413
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 192ms/step - loss: 0.7581 - sparse_categorical_accuracy: 0.7434 - val_loss: 0.7952 - val_sparse_categorical_accuracy: 0.7607 - learning_rate: 5.0000e-04
# Epoch 21/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.7339 - sparse_categorical_accuracy: 0.7673
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.83413
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - loss: 0.7224 - sparse_categorical_accuracy: 0.7635 - val_loss: 3.6451 - val_sparse_categorical_accuracy: 0.4405 - learning_rate: 5.0000e-04
# Epoch 22/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.7203 - sparse_categorical_accuracy: 0.7751
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.83413
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 197ms/step - loss: 0.6946 - sparse_categorical_accuracy: 0.7803 - val_loss: 1.3268 - val_sparse_categorical_accuracy: 0.7070 - learning_rate: 5.0000e-04
# Epoch 23/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.6765 - sparse_categorical_accuracy: 0.7922
# Epoch 23: val_sparse_categorical_accuracy improved from 0.83413 to 0.87559, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 23: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - loss: 0.6456 - sparse_categorical_accuracy: 0.7968 - val_loss: 0.5581 - val_sparse_categorical_accuracy: 0.8756 - learning_rate: 1.0000e-04
# Epoch 24/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.6041 - sparse_categorical_accuracy: 0.8070
# Epoch 24: val_sparse_categorical_accuracy improved from 0.87559 to 0.88171, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 24: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 194ms/step - loss: 0.6073 - sparse_categorical_accuracy: 0.8113 - val_loss: 0.5506 - val_sparse_categorical_accuracy: 0.8817 - learning_rate: 1.0000e-04
# Epoch 25/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.6135 - sparse_categorical_accuracy: 0.8105
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.88171
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s 213ms/step - loss: 0.5991 - sparse_categorical_accuracy: 0.8145 - val_loss: 0.5884 - val_sparse_categorical_accuracy: 0.8749 - learning_rate: 1.0000e-04
# Epoch 26/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.6039 - sparse_categorical_accuracy: 0.8118
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.88171
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - loss: 0.6000 - sparse_categorical_accuracy: 0.8107 - val_loss: 0.5906 - val_sparse_categorical_accuracy: 0.8810 - learning_rate: 1.0000e-04
# Epoch 27/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.5833 - sparse_categorical_accuracy: 0.8296
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.88171
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 193ms/step - loss: 0.5811 - sparse_categorical_accuracy: 0.8243 - val_loss: 0.5293 - val_sparse_categorical_accuracy: 0.8715 - learning_rate: 1.0000e-04
# Epoch 28/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.5703 - sparse_categorical_accuracy: 0.8295
# Epoch 28: val_sparse_categorical_accuracy improved from 0.88171 to 0.89259, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 28: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s 208ms/step - loss: 0.5712 - sparse_categorical_accuracy: 0.8283 - val_loss: 0.5185 - val_sparse_categorical_accuracy: 0.8926 - learning_rate: 1.0000e-04
# Epoch 29/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.5486 - sparse_categorical_accuracy: 0.8294
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.89259
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 194ms/step - loss: 0.5476 - sparse_categorical_accuracy: 0.8390 - val_loss: 0.7279 - val_sparse_categorical_accuracy: 0.7396 - learning_rate: 1.0000e-04
# Epoch 30/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.5543 - sparse_categorical_accuracy: 0.8391
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.89259
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - loss: 0.5670 - sparse_categorical_accuracy: 0.8334 - val_loss: 0.4810 - val_sparse_categorical_accuracy: 0.8824 - learning_rate: 1.0000e-04
# Epoch 31/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.5955 - sparse_categorical_accuracy: 0.8240
# Epoch 31: val_sparse_categorical_accuracy improved from 0.89259 to 0.89871, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 31: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - loss: 0.5609 - sparse_categorical_accuracy: 0.8340 - val_loss: 0.4882 - val_sparse_categorical_accuracy: 0.8987 - learning_rate: 1.0000e-04
# Epoch 32/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.5248 - sparse_categorical_accuracy: 0.8483
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.89871
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - loss: 0.5355 - sparse_categorical_accuracy: 0.8461 - val_loss: 0.7455 - val_sparse_categorical_accuracy: 0.7723 - learning_rate: 1.0000e-04
# Epoch 33/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.5325 - sparse_categorical_accuracy: 0.8442
# Epoch 33: val_sparse_categorical_accuracy improved from 0.89871 to 0.90891, saving model to UCI_HAR_RNN_best.keras
#
# Epoch 33: finished saving model to UCI_HAR_RNN_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - loss: 0.5390 - sparse_categorical_accuracy: 0.8407 - val_loss: 0.4722 - val_sparse_categorical_accuracy: 0.9089 - learning_rate: 1.0000e-04
# Epoch 34/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.5240 - sparse_categorical_accuracy: 0.8467
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - loss: 0.5272 - sparse_categorical_accuracy: 0.8442 - val_loss: 0.5671 - val_sparse_categorical_accuracy: 0.8348 - learning_rate: 1.0000e-04
# Epoch 35/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.5071 - sparse_categorical_accuracy: 0.8653
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 218ms/step - loss: 0.5101 - sparse_categorical_accuracy: 0.8567 - val_loss: 0.4403 - val_sparse_categorical_accuracy: 0.9048 - learning_rate: 1.0000e-04
# Epoch 36/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.5088 - sparse_categorical_accuracy: 0.8589
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 196ms/step - loss: 0.5073 - sparse_categorical_accuracy: 0.8524 - val_loss: 0.5576 - val_sparse_categorical_accuracy: 0.8436 - learning_rate: 1.0000e-04
# Epoch 37/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.4867 - sparse_categorical_accuracy: 0.8613
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 190ms/step - loss: 0.5104 - sparse_categorical_accuracy: 0.8510 - val_loss: 0.6175 - val_sparse_categorical_accuracy: 0.8103 - learning_rate: 1.0000e-04
# Epoch 38/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.5102 - sparse_categorical_accuracy: 0.8495
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - loss: 0.4984 - sparse_categorical_accuracy: 0.8560 - val_loss: 0.6404 - val_sparse_categorical_accuracy: 0.7838 - learning_rate: 1.0000e-04
# Epoch 39/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.4777 - sparse_categorical_accuracy: 0.8587
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - loss: 0.4896 - sparse_categorical_accuracy: 0.8575 - val_loss: 0.6192 - val_sparse_categorical_accuracy: 0.7777 - learning_rate: 1.0000e-04
# Epoch 40/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.4820 - sparse_categorical_accuracy: 0.8608
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 202ms/step - loss: 0.4755 - sparse_categorical_accuracy: 0.8652 - val_loss: 0.4536 - val_sparse_categorical_accuracy: 0.8926 - learning_rate: 1.0000e-04
# Epoch 41/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.4770 - sparse_categorical_accuracy: 0.8684
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 192ms/step - loss: 0.4765 - sparse_categorical_accuracy: 0.8635 - val_loss: 0.5488 - val_sparse_categorical_accuracy: 0.8674 - learning_rate: 1.0000e-04
# Epoch 42/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.4826 - sparse_categorical_accuracy: 0.8719
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 190ms/step - loss: 0.5129 - sparse_categorical_accuracy: 0.8544 - val_loss: 0.6061 - val_sparse_categorical_accuracy: 0.8436 - learning_rate: 1.0000e-04
# Epoch 43/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.4782 - sparse_categorical_accuracy: 0.8607
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 198ms/step - loss: 0.4756 - sparse_categorical_accuracy: 0.8612 - val_loss: 0.5210 - val_sparse_categorical_accuracy: 0.8402 - learning_rate: 1.0000e-04
# Epoch 44/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.4921 - sparse_categorical_accuracy: 0.8602
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - loss: 0.4785 - sparse_categorical_accuracy: 0.8652 - val_loss: 0.4853 - val_sparse_categorical_accuracy: 0.8545 - learning_rate: 1.0000e-04
# Epoch 45/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.4565 - sparse_categorical_accuracy: 0.8653
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.90891
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 193ms/step - loss: 0.4542 - sparse_categorical_accuracy: 0.8708 - val_loss: 0.6146 - val_sparse_categorical_accuracy: 0.7954 - learning_rate: 1.0000e-04
# Epoch 46/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.4553 - sparse_categorical_accuracy: 0.8596
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 192ms/step - loss: 0.4513 - sparse_categorical_accuracy: 0.8682 - val_loss: 0.4993 - val_sparse_categorical_accuracy: 0.8362 - learning_rate: 2.0000e-05
# Epoch 47/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.4376 - sparse_categorical_accuracy: 0.8815
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 208ms/step - loss: 0.4307 - sparse_categorical_accuracy: 0.8827 - val_loss: 0.5173 - val_sparse_categorical_accuracy: 0.8362 - learning_rate: 2.0000e-05
# Epoch 48/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.4173 - sparse_categorical_accuracy: 0.8869
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 195ms/step - loss: 0.4185 - sparse_categorical_accuracy: 0.8835 - val_loss: 0.5250 - val_sparse_categorical_accuracy: 0.8253 - learning_rate: 2.0000e-05
# Epoch 49/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.4207 - sparse_categorical_accuracy: 0.8799
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 192ms/step - loss: 0.4305 - sparse_categorical_accuracy: 0.8764 - val_loss: 0.5069 - val_sparse_categorical_accuracy: 0.8314 - learning_rate: 2.0000e-05
# Epoch 50/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.4324 - sparse_categorical_accuracy: 0.8777
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 193ms/step - loss: 0.4226 - sparse_categorical_accuracy: 0.8827 - val_loss: 0.5379 - val_sparse_categorical_accuracy: 0.8205 - learning_rate: 2.0000e-05
# Epoch 51/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.4314 - sparse_categorical_accuracy: 0.8750
# Epoch 51: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 196ms/step - loss: 0.4293 - sparse_categorical_accuracy: 0.8764 - val_loss: 0.5397 - val_sparse_categorical_accuracy: 0.8266 - learning_rate: 2.0000e-05
# Epoch 52/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.4309 - sparse_categorical_accuracy: 0.8773
# Epoch 52: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 192ms/step - loss: 0.4318 - sparse_categorical_accuracy: 0.8779 - val_loss: 0.5818 - val_sparse_categorical_accuracy: 0.8103 - learning_rate: 2.0000e-05
# Epoch 53/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.4281 - sparse_categorical_accuracy: 0.8807
# Epoch 53: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 192ms/step - loss: 0.4392 - sparse_categorical_accuracy: 0.8786 - val_loss: 0.5910 - val_sparse_categorical_accuracy: 0.7967 - learning_rate: 2.0000e-05
# Epoch 54/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.4329 - sparse_categorical_accuracy: 0.8796
# Epoch 54: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - loss: 0.4278 - sparse_categorical_accuracy: 0.8834 - val_loss: 0.6005 - val_sparse_categorical_accuracy: 0.7947 - learning_rate: 2.0000e-05
# Epoch 55/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.4208 - sparse_categorical_accuracy: 0.8872
# Epoch 55: val_sparse_categorical_accuracy did not improve from 0.90891
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 205ms/step - loss: 0.4268 - sparse_categorical_accuracy: 0.8835 - val_loss: 0.5880 - val_sparse_categorical_accuracy: 0.7933 - learning_rate: 2.0000e-05
# Epoch 56/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.4316 - sparse_categorical_accuracy: 0.8791
# Epoch 56: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 198ms/step - loss: 0.4243 - sparse_categorical_accuracy: 0.8815 - val_loss: 0.5381 - val_sparse_categorical_accuracy: 0.8287 - learning_rate: 1.0000e-05
# Epoch 57/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.4273 - sparse_categorical_accuracy: 0.8897
# Epoch 57: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 196ms/step - loss: 0.4161 - sparse_categorical_accuracy: 0.8908 - val_loss: 0.5663 - val_sparse_categorical_accuracy: 0.8103 - learning_rate: 1.0000e-05
# Epoch 58/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.4307 - sparse_categorical_accuracy: 0.8806
# Epoch 58: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 193ms/step - loss: 0.4203 - sparse_categorical_accuracy: 0.8837 - val_loss: 0.5837 - val_sparse_categorical_accuracy: 0.7995 - learning_rate: 1.0000e-05
# Epoch 59/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.4102 - sparse_categorical_accuracy: 0.8876
# Epoch 59: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 194ms/step - loss: 0.4138 - sparse_categorical_accuracy: 0.8847 - val_loss: 0.5735 - val_sparse_categorical_accuracy: 0.8137 - learning_rate: 1.0000e-05
# Epoch 60/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.4218 - sparse_categorical_accuracy: 0.8791
# Epoch 60: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 201ms/step - loss: 0.4130 - sparse_categorical_accuracy: 0.8817 - val_loss: 0.5524 - val_sparse_categorical_accuracy: 0.8178 - learning_rate: 1.0000e-05
# Epoch 61/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.4075 - sparse_categorical_accuracy: 0.8908
# Epoch 61: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - loss: 0.4175 - sparse_categorical_accuracy: 0.8818 - val_loss: 0.5645 - val_sparse_categorical_accuracy: 0.8090 - learning_rate: 1.0000e-05
# Epoch 62/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.4200 - sparse_categorical_accuracy: 0.8835
# Epoch 62: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 194ms/step - loss: 0.4091 - sparse_categorical_accuracy: 0.8915 - val_loss: 0.5229 - val_sparse_categorical_accuracy: 0.8314 - learning_rate: 1.0000e-05
# Epoch 63/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.4115 - sparse_categorical_accuracy: 0.8878
# Epoch 63: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 200ms/step - loss: 0.4156 - sparse_categorical_accuracy: 0.8859 - val_loss: 0.5755 - val_sparse_categorical_accuracy: 0.8260 - learning_rate: 1.0000e-05
# Epoch 63: early stopping
# Restoring model weights from the end of the best epoch: 33.

# %% [markdown]
# # 모델 평가

# %%
# best 기록 확인
model = tf.keras.models.load_model("UCI_HAR_RNN_best.keras")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# Training accuracy: 92.49%
# Training loss: 0.3590
# Test accuracy: 88.39%
# Test loss: 0.5537

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9242    0.9335    0.9288       496
#            1     0.9083    0.8832    0.8956       471
#            2     0.8632    0.9619    0.9099       420
#            3     0.8288    0.7495    0.7872       491
#            4     0.7965    0.8534    0.8240       532
#            5     0.9881    0.9311    0.9588       537
#
#     accuracy                         0.8839      2947
#    macro avg     0.8849    0.8854    0.8840      2947
# weighted avg     0.8857    0.8839    0.8837      2947

# %%
# loss / accuracy 그래프
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# 히트맵
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
