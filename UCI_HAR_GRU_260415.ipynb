# %% [markdown]
# # **UCI HAR - GRU Classification**

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, BatchNormalization, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

LABELS = [
    "WALKING",
    "WALKING_UPSTAIRS",
    "WALKING_DOWNSTAIRS",
    "SITTING",
    "STANDING",
    "LAYING"
]

# %%
TRAIN = "train/"
TEST = "test/"

DATASET_PATH = "/content/drive/MyDrive/AI_assignment/UCI_HAR_Dataset/"

# %%
# Load "X"
def load_X(X_signals_paths):
    X_signals = []

    for signal_type_path in X_signals_paths:
        series_list = []  # 한 센서축 데이터 전체 저장

        with open(signal_type_path, 'r') as file:
            for row in file:
                row_clean = row.replace('  ', ' ') # 공백 2개를 1개로
                row_clean = row_clean.strip() # 양쪽 공백 제거
                serie = row_clean.split(' ') # 공백 기준 split
                serie_array = np.array(serie, dtype=np.float32) # float32 numpy 배열로 변환
                series_list.append(serie_array) # 시퀀스 추가

        # 하나의 센서축 데이터 추가 (feature)
        X_signals.append(series_list)

    # shape: (특성 수, 샘플 수, 타임스텝 수)
    X_signals = np.array(X_signals)
    # shape 변환 → (샘플 수, 타임스텝 수, 특성 수)
    return np.transpose(X_signals, (1, 2, 0))


X_train_signals_paths = [
    DATASET_PATH + TRAIN + "Inertial_Signals/" + signal + "train.txt"
    for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    DATASET_PATH + TEST + "Inertial_Signals/" + signal + "test.txt"
    for signal in INPUT_SIGNAL_TYPES
]

X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("첫 번째 샘플 데이터:\n", X_train[0])
# Out:
# X_train shape: (7352, 128, 9)
# X_test shape: (2947, 128, 9)
# 첫 번째 샘플 데이터:
#  [[ 1.808515e-04  1.076681e-02  5.556068e-02 ...  1.012817e+00
#   -1.232167e-01  1.029341e-01]
#  [ 1.013856e-02  6.579480e-03  5.512483e-02 ...  1.022833e+00
#   -1.268756e-01  1.056872e-01]
#  [ 9.275574e-03  8.928878e-03  4.840473e-02 ...  1.022028e+00
#   -1.240037e-01  1.021025e-01]
#  ...
#  [-1.147484e-03  1.714439e-04  2.647864e-03 ...  1.018445e+00
#   -1.240696e-01  1.003852e-01]
#  [-2.222655e-04  1.574181e-03  2.381057e-03 ...  1.019372e+00
#   -1.227451e-01  9.987355e-02]
#  [ 1.575500e-03  3.070189e-03 -2.269757e-03 ...  1.021171e+00
#   -1.213260e-01  9.498741e-02]]

# %%
# Load "y"

def load_y(y_path):
    with open(y_path, 'r') as file:
        labels = [int(line.strip()) for line in file]
    # 라벨을 0부터 시작하도록 -1 (원래 라벨이 1부터 시)
    return np.array(labels, dtype=np.int32) - 1


y_train_path = DATASET_PATH + TRAIN + "y_train.txt"
y_test_path = DATASET_PATH + TEST + "y_test.txt"

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)

print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
print(y_train[:5])
# Out:
# y_train shape: (7352,)
# y_test shape: (2947,)
# [4 4 4 4 4]

# %% [markdown]
# # 모델 생성

# %%
input_shape = (X_train.shape[1], X_train.shape[2])
num_classes = 6

K.clear_session()

model = Sequential([
            Input(shape=input_shape),

            # 첫번째 GRU층
            GRU(64, return_sequences=True, dropout=0.3),
            BatchNormalization(),

            # 두번째 GRU층
            GRU(128, return_sequences=False, dropout=0.3),
            BatchNormalization(),

            # Dense층 2개
            Dense(32, activation='relu'),
            BatchNormalization(),
            Dropout(0.3),
            Dense(num_classes, activation='softmax')
        ])

model.compile(
            optimizer='adam',
            loss='sparse_categorical_crossentropy',
            metrics=['sparse_categorical_accuracy']
        )

print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 128, 64)        │        14,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 128)            │        74,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,118 (367.65 KB)
#  Trainable params: 93,670 (365.90 KB)
#  Non-trainable params: 448 (1.75 KB)
# None

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# # callbacks

# %%
callbacks = [
            ModelCheckpoint(
                "UCI_HAR_GRU_best.keras",
                save_best_only=True,
                monitor="val_sparse_categorical_accuracy",
                mode='max',
                verbose=1
            ),
            EarlyStopping(
                monitor="val_sparse_categorical_accuracy",
                patience=30,
                verbose=1,
                mode='max',
                restore_best_weights=True
            ),
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=5,
                min_lr=0.00001,
                verbose=1
            )
        ]

# %% [markdown]
# # 모델 학습

# %%
history = model.fit(
            X_train, y_train,
            epochs=100,
            batch_size=64,
            validation_split=0.2,
            callbacks=callbacks,
            verbose=1
        )
# Out:
# Epoch 1/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.6999 - sparse_categorical_accuracy: 0.3873
# Epoch 1: val_sparse_categorical_accuracy improved from None to 0.60843, saving model to UCI_HAR_GRU_best.keras
#
# Epoch 1: finished saving model to UCI_HAR_GRU_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 1.3729 - sparse_categorical_accuracy: 0.4695 - val_loss: 1.4492 - val_sparse_categorical_accuracy: 0.6084 - learning_rate: 0.0010
# Epoch 2/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0381 - sparse_categorical_accuracy: 0.5560
# Epoch 2: val_sparse_categorical_accuracy did not improve from 0.60843
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.9874 - sparse_categorical_accuracy: 0.5727 - val_loss: 1.5731 - val_sparse_categorical_accuracy: 0.3759 - learning_rate: 0.0010
# Epoch 3/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8632 - sparse_categorical_accuracy: 0.6274
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.60843
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.8392 - sparse_categorical_accuracy: 0.6368 - val_loss: 1.5484 - val_sparse_categorical_accuracy: 0.4371 - learning_rate: 0.0010
# Epoch 4/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7348 - sparse_categorical_accuracy: 0.6828
# Epoch 4: val_sparse_categorical_accuracy improved from 0.60843 to 0.75119, saving model to UCI_HAR_GRU_best.keras
#
# Epoch 4: finished saving model to UCI_HAR_GRU_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.7176 - sparse_categorical_accuracy: 0.6897 - val_loss: 0.8453 - val_sparse_categorical_accuracy: 0.7512 - learning_rate: 0.0010
# Epoch 5/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6267 - sparse_categorical_accuracy: 0.7319
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.75119
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.5949 - sparse_categorical_accuracy: 0.7506 - val_loss: 0.6859 - val_sparse_categorical_accuracy: 0.6560 - learning_rate: 0.0010
# Epoch 6/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5113 - sparse_categorical_accuracy: 0.7944
# Epoch 6: val_sparse_categorical_accuracy improved from 0.75119 to 0.88103, saving model to UCI_HAR_GRU_best.keras
#
# Epoch 6: finished saving model to UCI_HAR_GRU_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.4781 - sparse_categorical_accuracy: 0.8050 - val_loss: 0.3789 - val_sparse_categorical_accuracy: 0.8810 - learning_rate: 0.0010
# Epoch 7/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4356 - sparse_categorical_accuracy: 0.8260
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.88103
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.4395 - sparse_categorical_accuracy: 0.8199 - val_loss: 0.5236 - val_sparse_categorical_accuracy: 0.8464 - learning_rate: 0.0010
# Epoch 8/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4273 - sparse_categorical_accuracy: 0.8163
# Epoch 8: val_sparse_categorical_accuracy improved from 0.88103 to 0.90755, saving model to UCI_HAR_GRU_best.keras
#
# Epoch 8: finished saving model to UCI_HAR_GRU_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.4081 - sparse_categorical_accuracy: 0.8213 - val_loss: 0.3118 - val_sparse_categorical_accuracy: 0.9075 - learning_rate: 0.0010
# Epoch 9/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3915 - sparse_categorical_accuracy: 0.8367
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.90755
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.4023 - sparse_categorical_accuracy: 0.8279 - val_loss: 0.3185 - val_sparse_categorical_accuracy: 0.8851 - learning_rate: 0.0010
# Epoch 10/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3793 - sparse_categorical_accuracy: 0.8340
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.90755
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.3753 - sparse_categorical_accuracy: 0.8371 - val_loss: 0.3612 - val_sparse_categorical_accuracy: 0.8498 - learning_rate: 0.0010
# Epoch 11/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3671 - sparse_categorical_accuracy: 0.8432
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.90755
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.3598 - sparse_categorical_accuracy: 0.8444 - val_loss: 0.3915 - val_sparse_categorical_accuracy: 0.8097 - learning_rate: 0.0010
# Epoch 12/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3572 - sparse_categorical_accuracy: 0.8427
# Epoch 12: val_sparse_categorical_accuracy improved from 0.90755 to 0.90891, saving model to UCI_HAR_GRU_best.keras
#
# Epoch 12: finished saving model to UCI_HAR_GRU_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.3406 - sparse_categorical_accuracy: 0.8512 - val_loss: 0.3005 - val_sparse_categorical_accuracy: 0.9089 - learning_rate: 0.0010
# Epoch 13/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3442 - sparse_categorical_accuracy: 0.8538
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.3370 - sparse_categorical_accuracy: 0.8531 - val_loss: 0.8190 - val_sparse_categorical_accuracy: 0.6832 - learning_rate: 0.0010
# Epoch 14/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3376 - sparse_categorical_accuracy: 0.8488
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.3343 - sparse_categorical_accuracy: 0.8534 - val_loss: 0.3937 - val_sparse_categorical_accuracy: 0.8097 - learning_rate: 0.0010
# Epoch 15/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3256 - sparse_categorical_accuracy: 0.8572
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.3220 - sparse_categorical_accuracy: 0.8609 - val_loss: 0.3039 - val_sparse_categorical_accuracy: 0.8756 - learning_rate: 0.0010
# Epoch 16/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3172 - sparse_categorical_accuracy: 0.8545
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.3150 - sparse_categorical_accuracy: 0.8599 - val_loss: 0.3050 - val_sparse_categorical_accuracy: 0.9055 - learning_rate: 0.0010
# Epoch 17/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3099 - sparse_categorical_accuracy: 0.8575
# Epoch 17: val_sparse_categorical_accuracy did not improve from 0.90891
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.3154 - sparse_categorical_accuracy: 0.8544 - val_loss: 0.3972 - val_sparse_categorical_accuracy: 0.7797 - learning_rate: 0.0010
# Epoch 18/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2960 - sparse_categorical_accuracy: 0.8704
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2979 - sparse_categorical_accuracy: 0.8669 - val_loss: 0.3800 - val_sparse_categorical_accuracy: 0.8212 - learning_rate: 2.0000e-04
# Epoch 19/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2725 - sparse_categorical_accuracy: 0.8732
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.2758 - sparse_categorical_accuracy: 0.8716 - val_loss: 0.4801 - val_sparse_categorical_accuracy: 0.7709 - learning_rate: 2.0000e-04
# Epoch 20/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2858 - sparse_categorical_accuracy: 0.8626
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.2887 - sparse_categorical_accuracy: 0.8626 - val_loss: 0.3806 - val_sparse_categorical_accuracy: 0.8076 - learning_rate: 2.0000e-04
# Epoch 21/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2846 - sparse_categorical_accuracy: 0.8707
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2826 - sparse_categorical_accuracy: 0.8691 - val_loss: 0.4648 - val_sparse_categorical_accuracy: 0.7702 - learning_rate: 2.0000e-04
# Epoch 22/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2916 - sparse_categorical_accuracy: 0.8619
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.90891
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2745 - sparse_categorical_accuracy: 0.8703 - val_loss: 0.4598 - val_sparse_categorical_accuracy: 0.7770 - learning_rate: 2.0000e-04
# Epoch 23/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2704 - sparse_categorical_accuracy: 0.8697
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2730 - sparse_categorical_accuracy: 0.8696 - val_loss: 0.4393 - val_sparse_categorical_accuracy: 0.7859 - learning_rate: 4.0000e-05
# Epoch 24/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2716 - sparse_categorical_accuracy: 0.8734
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2675 - sparse_categorical_accuracy: 0.8774 - val_loss: 0.4478 - val_sparse_categorical_accuracy: 0.7757 - learning_rate: 4.0000e-05
# Epoch 25/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2871 - sparse_categorical_accuracy: 0.8712
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2818 - sparse_categorical_accuracy: 0.8718 - val_loss: 0.4644 - val_sparse_categorical_accuracy: 0.7702 - learning_rate: 4.0000e-05
# Epoch 26/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2622 - sparse_categorical_accuracy: 0.8683
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.2713 - sparse_categorical_accuracy: 0.8658 - val_loss: 0.4497 - val_sparse_categorical_accuracy: 0.7736 - learning_rate: 4.0000e-05
# Epoch 27/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2870 - sparse_categorical_accuracy: 0.8585
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.90891
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1e-05.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.2719 - sparse_categorical_accuracy: 0.8720 - val_loss: 0.4449 - val_sparse_categorical_accuracy: 0.7852 - learning_rate: 4.0000e-05
# Epoch 28/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2868 - sparse_categorical_accuracy: 0.8622
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2782 - sparse_categorical_accuracy: 0.8696 - val_loss: 0.4458 - val_sparse_categorical_accuracy: 0.7852 - learning_rate: 1.0000e-05
# Epoch 29/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2700 - sparse_categorical_accuracy: 0.8746
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2676 - sparse_categorical_accuracy: 0.8757 - val_loss: 0.4533 - val_sparse_categorical_accuracy: 0.7845 - learning_rate: 1.0000e-05
# Epoch 30/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2684 - sparse_categorical_accuracy: 0.8753
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2759 - sparse_categorical_accuracy: 0.8754 - val_loss: 0.4503 - val_sparse_categorical_accuracy: 0.7845 - learning_rate: 1.0000e-05
# Epoch 31/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2735 - sparse_categorical_accuracy: 0.8678
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2680 - sparse_categorical_accuracy: 0.8735 - val_loss: 0.4469 - val_sparse_categorical_accuracy: 0.7845 - learning_rate: 1.0000e-05
# Epoch 32/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2825 - sparse_categorical_accuracy: 0.8674
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2730 - sparse_categorical_accuracy: 0.8720 - val_loss: 0.4536 - val_sparse_categorical_accuracy: 0.7845 - learning_rate: 1.0000e-05
# Epoch 33/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2632 - sparse_categorical_accuracy: 0.8686
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.2623 - sparse_categorical_accuracy: 0.8721 - val_loss: 0.4469 - val_sparse_categorical_accuracy: 0.7845 - learning_rate: 1.0000e-05
# Epoch 34/100
# 90/92 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2408 - sparse_categorical_accuracy: 0.8853
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.2556 - sparse_categorical_accuracy: 0.8771 - val_loss: 0.4554 - val_sparse_categorical_accuracy: 0.7838 - learning_rate: 1.0000e-05
# Epoch 35/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2750 - sparse_categorical_accuracy: 0.8718
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2681 - sparse_categorical_accuracy: 0.8706 - val_loss: 0.4633 - val_sparse_categorical_accuracy: 0.7777 - learning_rate: 1.0000e-05
# Epoch 36/100
# 89/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2762 - sparse_categorical_accuracy: 0.8693
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2731 - sparse_categorical_accuracy: 0.8716 - val_loss: 0.4566 - val_sparse_categorical_accuracy: 0.7838 - learning_rate: 1.0000e-05
# Epoch 37/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2767 - sparse_categorical_accuracy: 0.8694
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2730 - sparse_categorical_accuracy: 0.8726 - val_loss: 0.4590 - val_sparse_categorical_accuracy: 0.7838 - learning_rate: 1.0000e-05
# Epoch 38/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2810 - sparse_categorical_accuracy: 0.8678
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2756 - sparse_categorical_accuracy: 0.8709 - val_loss: 0.4602 - val_sparse_categorical_accuracy: 0.7838 - learning_rate: 1.0000e-05
# Epoch 39/100
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2824 - sparse_categorical_accuracy: 0.8738
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2766 - sparse_categorical_accuracy: 0.8709 - val_loss: 0.4647 - val_sparse_categorical_accuracy: 0.7811 - learning_rate: 1.0000e-05
# Epoch 40/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2605 - sparse_categorical_accuracy: 0.8744
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.2683 - sparse_categorical_accuracy: 0.8709 - val_loss: 0.4643 - val_sparse_categorical_accuracy: 0.7838 - learning_rate: 1.0000e-05
# Epoch 41/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2707 - sparse_categorical_accuracy: 0.8747
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.2695 - sparse_categorical_accuracy: 0.8772 - val_loss: 0.4648 - val_sparse_categorical_accuracy: 0.7791 - learning_rate: 1.0000e-05
# Epoch 42/100
# 91/92 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2760 - sparse_categorical_accuracy: 0.8714
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.90891
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.2656 - sparse_categorical_accuracy: 0.8777 - val_loss: 0.4710 - val_sparse_categorical_accuracy: 0.7757 - learning_rate: 1.0000e-05
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 12.

# %% [markdown]
# # 모델 평가

# %%
# best 기록 확인
model = tf.keras.models.load_model("UCI_HAR_GRU_best.keras")

train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
print(f"Training accuracy: {train_acc * 100:.2f}%")
print(f"Training loss: {train_loss:.4f}")

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc * 100:.2f}%")
print(f"Test loss: {test_loss:.4f}")
# Out:
# Training accuracy: 93.09%
# Training loss: 0.1792
# Test accuracy: 91.04%
# Test loss: 0.2641

# %%
y_pred_proba = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_pred_proba, axis=1)

# 분류 리포트
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9855    0.9597    0.9724       496
#            1     0.9015    0.9915    0.9444       471
#            2     0.9876    0.9476    0.9672       420
#            3     0.8529    0.6965    0.7668       491
#            4     0.7942    0.8703    0.8305       532
#            5     0.9606    1.0000    0.9799       537
#
#     accuracy                         0.9104      2947
#    macro avg     0.9137    0.9109    0.9102      2947
# weighted avg     0.9112    0.9104    0.9087      2947

# %%
# loss / accuracy 그래프
train_loss = history.history['loss']
train_accuracy = history.history['sparse_categorical_accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_sparse_categorical_accuracy']

plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'r', label='Training loss')
plt.plot(val_loss, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_accuracy, 'r', label='Training Accuracy')
plt.plot(val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# 혼동행렬(히트맵)
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')

n_classes = len(np.unique(y_test))
if n_classes <= len(LABELS):
    plt.gca().set_xticklabels(LABELS[:n_classes], rotation=45, ha='right')
    plt.gca().set_yticklabels(LABELS[:n_classes], rotation=0)

plt.tight_layout()
plt.show()
